# %% [markdown]
# # Intro<br>
# This file is to get detailed information about cluster data whereby each cluster represents the types of interaction a journal entry has with its involved accounts
#
# Information:<ul>
# <li><b>Cluster_ID:</b> Unique number given to each cluster</li>
# <li><b>Cluster:</b> List of interactions with different accounts which make up the cluster name and uniqueness.<br> Format is interaction + account id (account number + account name)
#     <ul>
#         <li>Cr: Amount credited to account</li>
#         <li>Dr: Amount debited to account</li>
#         <li>Zero: 0 dollars were credited/debited to the account</li>
#     </ul>
# </li>
# <li><b>UniqueInteractions:</b> Count of the unique interactions + account IDs found in cluster (length of cluster)</li>
# <li><b>AccountCount:</b> Number of unique accounts found in the cluster (Number of unique accounts the journal documents inside the cluster interact with, which could be repeated ie an account could be both credited and debited)</li>
# <li><b>DocumentCount:</b> Number of unique journal documents inside each cluster</li>
# </ul><br>
# <b>Note: Please change saving location</b>

# %% [markdown]
# # Import data and libraries

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from importlib import reload
import pandas as pd
import numpy as np

import _00_util_sql
reload(_00_util_sql)
from _00_util_sql import Conn_ODBC

# %%
sql_db=Conn_ODBC(database="JE_ML_2025")

##### Import data 
conn=sql_db.odbc_conn_db_pyodbc()
sql_query=f"SELECT * FROM [data_Hailong_staging_JE_updated_All]"
data_22=sql_db.odbc_run_sql(conn, sql_query, return_result=True)
conn.close()

data_22.info()
# 1 mins
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51977 entries, 0 to 51976
# Data columns (total 51 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   CompanyName                             51977 non-null  object
#  1   ExcludeBalanceOnly                      51977 non-null  object
#  2   PrintReversedEntries                    51977 non-null  object
#  3   PageGroupNo                             51977 non-null  int64
#  4   PrintOnlyOnePerPage                     51977 non-null  object
#  5   PrintClosingEntries                     51977 non-null  object
#  6   PrintOnlyCorrections                    51977 non-null  object
#  7   EmptyString                             0 non-null      object
#  8   No_GLAcc                                51977 non-null  object
#  9   DetailTrialBalCaption                   51977 non-null  object
#  10  PageCaption                             51977 non-null  object
#  11  BalanceCaption                          51977 non-null  object
#  12  PeriodCaption                           51977 non-null  object
#  13  OnlyCorrectionsCaption                  51977 non-null  object
#  14  NetChangeCaption                        51977 non-null  object
#  15  GLEntryDebitAmtCaption                  51977 non-null  object
#  16  GLEntryCreditAmtCaption                 51977 non-null  object
#  17  GLBalCaption                            51977 non-null  object
#  18  Name_GLAcc                              51977 non-null  object
#  19  StartBalance                            51977 non-null  float64
#  20  VATAmount_GLEntry                       51977 non-null  float64
#  21  DebitAmount_GLEntry                     51977 non-null  float64
#  22  CreditAmount_GLEntry                    51977 non-null  float64
#  23  PostingDate_GLEntry                     51977 non-null  object
#  24  DocumentNo_GLEntry                      51977 non-null  object
#  25  ExtDocNo_GLEntry                        28366 non-null  object
#  26  Description_GLEntry                     51975 non-null  object
#  27  GLBalance                               51977 non-null  float64
#  28  EntryNo_GLEntry                         51977 non-null  int64
#  29  ClosingEntry                            51977 non-null  object
#  30  Reversed_GLEntry                        51977 non-null  object
#  31  DQ_Mismatch_JE_Amt                      51977 non-null  int64
#  32  DQ_Negative_Credit                      51977 non-null  int64
#  33  DQ_Negative_Debit                       51977 non-null  int64
#  34  DQ_Missing_COA                          51977 non-null  int64
#  35  DQ_Missing_Des                          51977 non-null  int64
#  36  DQ_one_holiday                          51977 non-null  int64
#  37  DQ_Duplicates                           51977 non-null  int64
#  38  Dup_JE_Same_GLAcc_Date_Amt              51977 non-null  int64
#  39  Dup_JE_Same_Description_GLAcc_Amt       51977 non-null  int64
#  40  DQ_Negative_Credit_or_Debit             51977 non-null  int64
#  41  Document_type                           40602 non-null  object
#  42  NO_OF_JE_LINES                          51977 non-null  int64
#  43  NO_OF_GL_ACC                            51977 non-null  int64
#  44  JE_Doc_no_Debit_amt                     51977 non-null  float64
#  45  Dup_JE_Same_GLAcc_Date_Description_Amt  51977 non-null  int64
#  46  NWH_holiday                             51977 non-null  int64
#  47  GL_Acc_Category                         51977 non-null  object
#  48  UT_unusual_pairing                      51977 non-null  int64
#  49  UT_dr_cr_liability                      51977 non-null  int64
#  50  UT_dr_liability_cr_income_exp           51977 non-null  int64
# dtypes: float64(6), int64(19), object(26)
# memory usage: 20.2+ MB

# %% [markdown]
# # Clustering

# %%
# Old
# Cluster journal documents (JE_Doc_ID) according to interaction and unique account. 
# JE_Doc_IDs can be repeated across clusters
def cluster_journal_entries(df):
    """
    Clusters journal entries into Dr/Cr/Zero groups by GL Account,
    and counts the number of unique JE documents per cluster.
    
    Parameters:
        df (pd.DataFrame): Input data containing JE base info
    
    Returns:
        pd.DataFrame: Clustered result with document counts
    """

    # Step 1: Determine Dr / Cr / Zero
    def get_cluster_type(row):
        if row['DebitAmount_GLEntry'] != 0:
            return f"Dr {row['No_GLAcc']} {row['Name_GLAcc']}"
        elif row['CreditAmount_GLEntry'] != 0:
            return f"Cr {row['No_GLAcc']} {row['Name_GLAcc']}"
        else:
            return f"Zero {row['No_GLAcc']} {row['Name_GLAcc']}"

    # Apply function to create cluster column
    df['Cluster'] = df.apply(get_cluster_type, axis=1)

    # Step 2: Create a unique identifier for each JE document
    df['JE_Doc_ID'] = df['CompanyName'] + '|' + df['DocumentNo_GLEntry'].astype(str)

    # Step 3: Group by Cluster and count unique JE documents
    result = (
        df[['Cluster', 'JE_Doc_ID']]
        .drop_duplicates()
        .groupby('Cluster')
        .size()
        .reset_index(name='JE_Count')
    )

    return result

# Run clustering
cluster_result = cluster_journal_entries(data_22)
cluster_result
# Out:
#                                          Cluster  JE_Count
# 0                Cr 10000000 Cash on Hands - TWD      3989
# 1                Cr 10000010 Cash on Hands - USD       722
# 2                Cr 10000020 Cash on Hands - EUR       816
# 3                Cr 10000045 Cash on Hands - JPY        17
# 4                 Cr 10000050 Time Deposit - TWD         2
# ..                                           ...       ...
# 236            Zero 60900200 Cost Capatalization         2
# 237     Zero 70010000 Foreign Exchange Gain/Loss         5
# 238  Zero 70010100 Unrealized Exchange Gain/Loss         4
# 239    Zero 70100000 Gain/Loss on Sale of Assets         1
# 240        Zero 80100000 Income Taxes - Deferred         4
#
# [241 rows x 2 columns]

# %%
# Old
def cluster_journal_entries_grouped_by_je(df):
    """
    Clusters journal entries into Dr/Cr/Zero groups by GL Account,
    grouped by Journal Entry (CompanyName + DocumentNo_GLEntry),
    and counts how many JE documents fall into each cluster.

    Parameters:
        df (pd.DataFrame): Input data containing JE base info
    
    Returns:
        pd.DataFrame: Clustered result with document counts
    """

    # Step 1: Determine Dr / Cr / Zero cluster per row
    def get_cluster_type(row):
        if row['DebitAmount_GLEntry'] != 0:
            return f"Dr {row['No_GLAcc']} {row['Name_GLAcc']}"
        elif row['CreditAmount_GLEntry'] != 0:
            return f"Cr {row['No_GLAcc']} {row['Name_GLAcc']}"
        else:
            return f"Zero {row['No_GLAcc']} {row['Name_GLAcc']}"

    df['Cluster'] = df.apply(get_cluster_type, axis=1)

    # Step 2: Create JE document ID
    df['JE_Doc_ID'] = df['CompanyName'].astype(str) + '|' + df['DocumentNo_GLEntry'].astype(str)

    # Step 3: For each JE document, collect all unique clusters it belongs to
    je_clusters = (
        df[['JE_Doc_ID', 'Cluster']]
        .drop_duplicates()
        .groupby('JE_Doc_ID')['Cluster']
        .apply(lambda x: tuple(sorted(x)))
        .reset_index()
    )

    return je_clusters

clus = cluster_journal_entries_grouped_by_je(data_22)
clus
# Out:
#                  JE_Doc_ID                                            Cluster
# 0      Hailong2|EX20221025  (Cr 70010000 Foreign Exchange Gain/Loss, Dr 10...
# 1      Hailong2|FX20221101  (Cr 10000020 Cash on Hands - EUR, Cr 70010000 ...
# 2      Hailong2|FX20221104  (Cr 10000010 Cash on Hands - USD, Cr 70010000 ...
# 3      Hailong2|FX20221201  (Cr 70010000 Foreign Exchange Gain/Loss, Dr 10...
# 4      Hailong2|FX20221202  (Cr 10000010 Cash on Hands - USD, Cr 70010000 ...
# ...                    ...                                                ...
# 16951  Hailong3|GJ24050528  (Cr 16100000 Construction in Progress, Dr 2002...
# 16952  Hailong3|GJ24050529  (Cr 14020000 Derivative Asset - Current, Cr 30...
# 16953  Hailong3|GJ24050530  (Cr 20800000 Deferred Tax Liabilities, Cr 3040...
# 16954  Hailong3|GJ24050531  (Cr 2060EDBS Bank Loan - EBL DBS, Cr 2060EMUFG...
# 16955  Hailong3|GJ24050532  (Cr 20800000 Deferred Tax Liabilities, Dr 8010...
#
# [16956 rows x 2 columns]

# %%
# Old
def cluster_journal_entries_grouped_by_je(df):
    """
    Clusters journal entries into Dr/Cr/Zero groups by GL Account,
    grouped by Journal Entry (CompanyName + DocumentNo_GLEntry),
    and counts how many JE documents fall into each *unique combination* of clusters.

    Parameters:
        df (pd.DataFrame): Input data containing JE base info

    Returns:
        pd.DataFrame: Each unique combination of clusters with a count of JE documents
    """

    def get_cluster_type(row):
        if row['DebitAmount_GLEntry'] != 0:
            return f"Dr {row['No_GLAcc']} {row['Name_GLAcc']}"
        elif row['CreditAmount_GLEntry'] != 0:
            return f"Cr {row['No_GLAcc']} {row['Name_GLAcc']}"
        else:
            return f"Zero {row['No_GLAcc']} {row['Name_GLAcc']}"

    df['Cluster'] = df.apply(get_cluster_type, axis=1)

    df['JE_Doc_ID'] = df['CompanyName'].astype(str) + '|' + df['DocumentNo_GLEntry'].astype(str)

    # Convert cluster list to tuple so it's hashable
    je_clusters = (
        df[['JE_Doc_ID', 'Cluster']]
        .drop_duplicates()
        .groupby('JE_Doc_ID')['Cluster']
        .apply(lambda x: tuple(sorted(x)))  # Convert to tuple after sorting, 
        # sorting to ensure the combis are organised and thus will be treated the same
        .reset_index()
    )

    grouped_counts = (
        je_clusters
        .groupby('Cluster')
        .size()
        .reset_index(name='DocumentCount')
        .sort_values(by='DocumentCount', ascending=False)
    )

    # Convert Cluster back to list for readability
    grouped_counts['Cluster'] = grouped_counts['Cluster'].apply(list)
    
    return grouped_counts

result = cluster_journal_entries_grouped_by_je(data_22)
result
# Out:
#                                                Cluster  DocumentCount
# 32   [Cr 10000000 Cash on Hands - TWD, Dr 20000000 ...           2034
# 386  [Cr 20000000 AP - Trade, Dr 11080000 Input VAT...           2028
# 398  [Cr 20000000 AP - Trade, Dr 16100000 Construct...           1993
# 37   [Cr 10000000 Cash on Hands - TWD, Dr 20010010 ...           1187
# 609  [Cr 20080000 Withholding Tax Payable, Dr 20000...           1074
# ..                                                 ...            ...
# 725  [Cr 70010000 Foreign Exchange Gain/Loss, Cr 70...              1
# 726  [Cr 70010000 Foreign Exchange Gain/Loss, Cr 70...              1
# 728  [Cr 70010000 Foreign Exchange Gain/Loss, Cr 70...              1
# 730  [Cr 70010000 Foreign Exchange Gain/Loss, Dr 10...              1
# 735  [Cr 70010000 Foreign Exchange Gain/Loss, Dr 20...              1
#
# [755 rows x 2 columns]

# %%
import pandas as pd
import re

def normalize_name(name):
    """Normalize account names for comparison"""
    name = str(name).lower()
    name = re.sub(r'[^a-z0-9\s]', '', name)  # Remove non-alphanumeric characters
    name = re.sub(r'\s+', ' ', name).strip()  # Normalize spacing
    return name

# Count number of UNIQUE accounts in each cluster
# Remove direction prefix (Dr/Cr/Zero) to get unique account ID
def count_unique_accounts(cluster_list):
    unique_accounts = set()
    for cluster_item in cluster_list:
        # Remove the direction prefix (first word) to get the account identifier
        account_id = ' '.join(cluster_item.split()[1:])  # Remove first word (Dr/Cr/Zero)
        unique_accounts.add(account_id)
    return len(unique_accounts)

def cluster_journal_entries_grouped_by_je(df):
    """
    Clusters journal entries into Dr/Cr/Zero groups by GL Account,
    grouped by Journal Entry (CompanyName + DocumentNo_GLEntry),
    and counts how many JE documents fall into each *unique combination* of clusters.

    Parameters:
        df (pd.DataFrame): Input data containing JE base info

    Returns:
        pd.DataFrame: Each unique combination of clusters with a count of JE documents
    """

    def get_cluster_type(row):
        if row['DebitAmount_GLEntry'] != 0:
            direction = 'Dr'
        elif row['CreditAmount_GLEntry'] != 0:
            direction = 'Cr'
        else:
            direction = 'Zero'

        # Use normalized name in the cluster key
        normalized_name = normalize_name(row['Name_GLAcc'])
        return f"{direction} {row['No_GLAcc']} {normalized_name}"

    df['Cluster'] = df.apply(get_cluster_type, axis=1)

    df['JE_Doc_ID'] = df['CompanyName'].astype(str) + '|' + df['DocumentNo_GLEntry'].astype(str) + '|' + df['PostingDate_GLEntry'].astype(str)

    # Convert cluster list to tuple so it's hashable
    je_clusters = (
        df[['JE_Doc_ID', 'Cluster']]
        .drop_duplicates()
        .groupby('JE_Doc_ID')['Cluster']
        .apply(lambda x: tuple(sorted(x)))  # Ensure consistent ordering
        .reset_index()
    )

    grouped_counts = (
        je_clusters
        .groupby('Cluster')
        .size()
        .reset_index(name='DocumentCount')
        .sort_values(by='DocumentCount', ascending=False)
    )

    # Optional: convert Cluster back to list for readability
    grouped_counts['Cluster'] = grouped_counts['Cluster'].apply(list)

    # Assign a unique cluster ID
    grouped_counts['Cluster_ID'] = [str(i) for i in range(1, len(grouped_counts) + 1)]

    # Count number of unique interactions in each cluster
    grouped_counts['UniqueInteractions'] = grouped_counts['Cluster'].apply(len)
  
    grouped_counts['AccountCount'] = grouped_counts['Cluster'].apply(count_unique_accounts)

    # Move Cluster_ID to the leftmost position
    grouped_counts = grouped_counts[['Cluster_ID', 'Cluster', 'UniqueInteractions','AccountCount', 'DocumentCount']]

    return grouped_counts
 
# Example usage
result = cluster_journal_entries_grouped_by_je(data_22)
result
# Out:
#     Cluster_ID                                            Cluster  \
# 30           1  [Cr 10000000 cash on hands twd, Dr 20000000 ap...
# 367          2  [Cr 20000000 ap trade, Dr 11080000 input vat, ...
# 379          3  [Cr 20000000 ap trade, Dr 16100000 constructio...
# 35           4  [Cr 10000000 cash on hands twd, Dr 20010010 ap...
# 590          5  [Cr 20080000 withholding tax payable, Dr 20000...
# ..         ...                                                ...
# 44         725  [Cr 10000000 cash on hands twd, Dr 20400000 ot...
# 46         726  [Cr 10000000 cash on hands twd, Dr 60325000 in...
# 697        727  [Cr 60900200 cost capitalization, Dr 16100000 ...
# 698        728  [Cr 60900200 cost capitalization, Dr 16100000 ...
# 699        729  [Cr 70010000 foreign exchange gainloss, Cr 700...
#
#      UniqueInteractions  AccountCount  DocumentCount
# 30                    2             2           2034
# 367                   3             3           2029
# 379                   2             2           1994
# 35                    2             2           1187
# 590                   2             2           1074
# ..                  ...           ...            ...
# 44                    3             3              1
# 46                    2             2              1
# 697                   2             2              1
# 698                   3             3              1
# 699                   5             3              1
#
# [729 rows x 5 columns]

# %% [markdown]
# ## Save

# %%
# Change where you want to save the dataframe
result.to_excel(rf"D:\Shared\Internal Dev - JE ML\Hailong\ManualCluster.xlsx", index=False)

# %% [markdown]
# # Clustering using Ishi code <br>
# Clustering done using old Ishi code, can be ignored

# %%
data_22['Dr_Cr'] = np.where(
    data_22['DebitAmount_GLEntry'] != 0, 'Dr',
    np.where(
        data_22['CreditAmount_GLEntry'] != 0, 'Cr',
        'Zero'
    )
)

data_22['Account'] = data_22['No_GLAcc'].astype(str) + ' ' + data_22['Name_GLAcc']

# %%
data_22['Dr_Cr'].value_counts()
# Out:
# Dr      28686
# Cr      22577
# Zero      714
# Name: Dr_Cr, dtype: int64

# %%
len(data_22['Account'].unique().tolist())
# Out:
# 116

# %%
data_22['Amt'] = data_22.apply(
    lambda row: row['DebitAmount_GLEntry'] if row['DebitAmount_GLEntry'] != 0 and row['CreditAmount_GLEntry'] == 0
    else row['CreditAmount_GLEntry'] if row['CreditAmount_GLEntry'] != 0 and row['DebitAmount_GLEntry'] == 0
    else 0,
    axis=1
)

data_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51977 entries, 0 to 51976
# Data columns (total 54 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   CompanyName                             51977 non-null  object
#  1   ExcludeBalanceOnly                      51977 non-null  object
#  2   PrintReversedEntries                    51977 non-null  object
#  3   PageGroupNo                             51977 non-null  object
#  4   PrintOnlyOnePerPage                     51977 non-null  object
#  5   PrintClosingEntries                     51977 non-null  object
#  6   PrintOnlyCorrections                    51977 non-null  object
#  7   EmptyString                             0 non-null      object
#  8   No_GLAcc                                51977 non-null  object
#  9   DetailTrialBalCaption                   51977 non-null  object
#  10  PageCaption                             51977 non-null  object
#  11  BalanceCaption                          51977 non-null  object
#  12  PeriodCaption                           51977 non-null  object
#  13  OnlyCorrectionsCaption                  51977 non-null  object
#  14  NetChangeCaption                        51977 non-null  object
#  15  GLEntryDebitAmtCaption                  51977 non-null  object
#  16  GLEntryCreditAmtCaption                 51977 non-null  object
#  17  GLBalCaption                            51977 non-null  object
#  18  Name_GLAcc                              51977 non-null  object
#  19  StartBalance                            51977 non-null  float64
#  20  VATAmount_GLEntry                       51977 non-null  float64
#  21  DebitAmount_GLEntry                     51977 non-null  float64
#  22  CreditAmount_GLEntry                    51977 non-null  float64
#  23  PostingDate_GLEntry                     51977 non-null  object
#  24  DocumentNo_GLEntry                      51977 non-null  object
#  25  ExtDocNo_GLEntry                        28366 non-null  object
#  26  Description_GLEntry                     51975 non-null  object
#  27  GLBalance                               51977 non-null  float64
#  28  EntryNo_GLEntry                         51977 non-null  object
#  29  ClosingEntry                            51977 non-null  object
#  30  Reversed_GLEntry                        51977 non-null  object
#  31  DQ_Mismatch_JE_Amt                      51977 non-null  int64
#  32  DQ_Negative_Credit                      51977 non-null  int64
#  33  DQ_Negative_Debit                       51977 non-null  int64
#  34  DQ_Missing_COA                          51977 non-null  int64
#  35  DQ_Missing_Des                          51977 non-null  int64
#  36  DQ_one_holiday                          51977 non-null  int64
#  37  DQ_Duplicates                           51977 non-null  int64
#  38  Dup_JE_Same_GLAcc_Date_Amt              51977 non-null  int64
#  39  Dup_JE_Same_Description_GLAcc_Amt       51977 non-null  int64
#  40  DQ_Negative_Credit_or_Debit             51977 non-null  int64
#  41  Document_type                           40602 non-null  object
#  42  NO_OF_JE_LINES                          51977 non-null  int64
#  43  NO_OF_GL_ACC                            51977 non-null  int64
#  44  JE_Doc_no_Debit_amt                     51977 non-null  float64
#  45  Dup_JE_Same_GLAcc_Date_Description_Amt  51977 non-null  int64
#  46  NWH_holiday                             51977 non-null  int64
#  47  GL_Acc_Category                         51977 non-null  object
#  48  UT_unusual_pairing                      51977 non-null  int64
#  49  UT_dr_cr_liability                      51977 non-null  int64
#  50  UT_dr_liability_cr_income_exp           51977 non-null  int64
#  51  Dr_Cr                                   51977 non-null  object
#  52  Account                                 51977 non-null  object
#  53  Amt                                     51977 non-null  float64
# dtypes: float64(7), int64(17), object(30)
# memory usage: 21.4+ MB

# %%
identifiers = ['CompanyName', 'DocumentNo_GLEntry']

# Create pivot table with multi-index columns
pivot = data_22.pivot_table(
    index=identifiers,
    columns=['Dr_Cr', 'Account'],
    values='Amt',
    aggfunc='sum'
)

# Flatten the column MultiIndex into single strings like "Dr_Asset"
pivot.columns = [f"{col[0]}_{col[1]}" for col in pivot.columns]

# After creating the pivot table
pivot_binary = pivot.fillna(0).applymap(lambda x: 1 if x != 0 else 0)
# pivot_binary = pivot.applymap(lambda x: 1 if x != 0 else 0)
pivot_binary
# pivot
# Out:
#                                 Cr_10000000 Cash on Hands - TWD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        0
#             FX20221104                                        0
#             FX20221201                                        0
#             FX20221202                                        0
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000010 Cash on Hands - USD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        0
#             FX20221104                                        1
#             FX20221201                                        0
#             FX20221202                                        1
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000020 Cash on Hands - EUR  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        1
#             FX20221104                                        0
#             FX20221201                                        0
#             FX20221202                                        0
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000045 Cash on Hands - JPY  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        0
#             FX20221104                                        0
#             FX20221201                                        0
#             FX20221202                                        0
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000050 Time Deposit - TWD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                       0
#             FX20221101                                       0
#             FX20221104                                       0
#             FX20221201                                       0
#             FX20221202                                       0
# ...                                                        ...
# Hailong3    GJ24050528                                       0
#             GJ24050529                                       0
#             GJ24050530                                       0
#             GJ24050531                                       0
#             GJ24050532                                       0
#
#                                 Cr_10000051 Time Deposit - USD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                       0
#             FX20221101                                       0
#             FX20221104                                       0
#             FX20221201                                       0
#             FX20221202                                       0
# ...                                                        ...
# Hailong3    GJ24050528                                       0
#             GJ24050529                                       0
#             GJ24050530                                       0
#             GJ24050531                                       0
#             GJ24050532                                       0
#
#                                 Cr_10000052 Time Deposit - EUR  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                       0
#             FX20221101                                       0
#             FX20221104                                       0
#             FX20221201                                       0
#             FX20221202                                       0
# ...                                                        ...
# Hailong3    GJ24050528                                       0
#             GJ24050529                                       0
#             GJ24050530                                       0
#             GJ24050531                                       0
#             GJ24050532                                       0
#
#                                 Cr_10010001 Restricted Cash - Time Deposit(NTD)  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                        0
#             FX20221101                                                        0
#             FX20221104                                                        0
#             FX20221201                                                        0
#             FX20221202                                                        0
# ...                                                                         ...
# Hailong3    GJ24050528                                                        0
#             GJ24050529                                                        0
#             GJ24050530                                                        0
#             GJ24050531                                                        0
#             GJ24050532                                                        0
#
#                                 Cr_10010001 Restricted Cash - Time Deposit(TWD)  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                        0
#             FX20221101                                                        0
#             FX20221104                                                        0
#             FX20221201                                                        0
#             FX20221202                                                        0
# ...                                                                         ...
# Hailong3    GJ24050528                                                        0
#             GJ24050529                                                        0
#             GJ24050530                                                        0
#             GJ24050531                                                        0
#             GJ24050532                                                        0
#
#                                 Cr_10010010 Restricted Cash - Time Deposit(EUR)  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                        0
#             FX20221101                                                        0
#             FX20221104                                                        0
#             FX20221201                                                        0
#             FX20221202                                                        0
# ...                                                                         ...
# Hailong3    GJ24050528                                                        0
#             GJ24050529                                                        0
#             GJ24050530                                                        0
#             GJ24050531                                                        0
#             GJ24050532                                                        0
#
#                                 ...  Zero_60040900 Other Operation Cost  \
# CompanyName DocumentNo_GLEntry  ...
# Hailong2    EX20221025          ...                                   0
#             FX20221101          ...                                   0
#             FX20221104          ...                                   0
#             FX20221201          ...                                   0
#             FX20221202          ...                                   0
# ...                             ...                                 ...
# Hailong3    GJ24050528          ...                                   0
#             GJ24050529          ...                                   0
#             GJ24050530          ...                                   0
#             GJ24050531          ...                                   0
#             GJ24050532          ...                                   0
#
#                                 Zero_60100000 Professional Fees  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        0
#             FX20221104                                        0
#             FX20221201                                        0
#             FX20221202                                        0
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Zero_60250000 Bank Charges  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                   0
#             FX20221101                                   0
#             FX20221104                                   0
#             FX20221201                                   0
#             FX20221202                                   0
# ...                                                    ...
# Hailong3    GJ24050528                                   0
#             GJ24050529                                   0
#             GJ24050530                                   0
#             GJ24050531                                   0
#             GJ24050532                                   0
#
#                                 Zero_60325000 Interest Income  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                      0
#             FX20221101                                      0
#             FX20221104                                      0
#             FX20221201                                      0
#             FX20221202                                      0
# ...                                                       ...
# Hailong3    GJ24050528                                      0
#             GJ24050529                                      0
#             GJ24050530                                      0
#             GJ24050531                                      0
#             GJ24050532                                      0
#
#                                 Zero_60900100 Cost Sharing - HL3  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                         0
#             FX20221101                                         0
#             FX20221104                                         0
#             FX20221201                                         0
#             FX20221202                                         0
# ...                                                          ...
# Hailong3    GJ24050528                                         0
#             GJ24050529                                         0
#             GJ24050530                                         0
#             GJ24050531                                         0
#             GJ24050532                                         0
#
#                                 Zero_60900200 Cost Capatalization  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                          0
#             FX20221101                                          0
#             FX20221104                                          0
#             FX20221201                                          0
#             FX20221202                                          0
# ...                                                           ...
# Hailong3    GJ24050528                                          0
#             GJ24050529                                          0
#             GJ24050530                                          0
#             GJ24050531                                          0
#             GJ24050532                                          0
#
#                                 Zero_70010000 Foreign Exchange Gain/Loss  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                 0
#             FX20221101                                                 0
#             FX20221104                                                 0
#             FX20221201                                                 0
#             FX20221202                                                 0
# ...                                                                  ...
# Hailong3    GJ24050528                                                 0
#             GJ24050529                                                 0
#             GJ24050530                                                 0
#             GJ24050531                                                 0
#             GJ24050532                                                 0
#
#                                 Zero_70010100 Unrealized Exchange Gain/Loss  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                    0
#             FX20221101                                                    0
#             FX20221104                                                    0
#             FX20221201                                                    0
#             FX20221202                                                    0
# ...                                                                     ...
# Hailong3    GJ24050528                                                    0
#             GJ24050529                                                    0
#             GJ24050530                                                    0
#             GJ24050531                                                    0
#             GJ24050532                                                    0
#
#                                 Zero_70100000 Gain/Loss on Sale of Assets  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                  0
#             FX20221101                                                  0
#             FX20221104                                                  0
#             FX20221201                                                  0
#             FX20221202                                                  0
# ...                                                                   ...
# Hailong3    GJ24050528                                                  0
#             GJ24050529                                                  0
#             GJ24050530                                                  0
#             GJ24050531                                                  0
#             GJ24050532                                                  0
#
#                                 Zero_80100000 Income Taxes - Deferred
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                              0
#             FX20221101                                              0
#             FX20221104                                              0
#             FX20221201                                              0
#             FX20221202                                              0
# ...                                                               ...
# Hailong3    GJ24050528                                              0
#             GJ24050529                                              0
#             GJ24050530                                              0
#             GJ24050531                                              0
#             GJ24050532                                              0
#
# [16956 rows x 241 columns]

# %%
features = pivot_binary.columns
print(len(features))
# Out:
# 241

# %%
# Create a signature string for each row
pivot_binary['Cluster_Signature'] = pivot_binary[features].apply(
    lambda row: ', '.join([col for col, val in row.items() if val != 0]), axis=1
)

# Now group by the signature to form clusters
clusters = pivot_binary.groupby('Cluster_Signature')

pivot_binary['Cluster_ID'] = pivot_binary.groupby('Cluster_Signature').ngroup()
pivot_binary
# Out:
#                                 Cr_10000000 Cash on Hands - TWD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        0
#             FX20221104                                        0
#             FX20221201                                        0
#             FX20221202                                        0
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000010 Cash on Hands - USD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        0
#             FX20221104                                        1
#             FX20221201                                        0
#             FX20221202                                        1
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000020 Cash on Hands - EUR  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        1
#             FX20221104                                        0
#             FX20221201                                        0
#             FX20221202                                        0
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000045 Cash on Hands - JPY  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                        0
#             FX20221101                                        0
#             FX20221104                                        0
#             FX20221201                                        0
#             FX20221202                                        0
# ...                                                         ...
# Hailong3    GJ24050528                                        0
#             GJ24050529                                        0
#             GJ24050530                                        0
#             GJ24050531                                        0
#             GJ24050532                                        0
#
#                                 Cr_10000050 Time Deposit - TWD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                       0
#             FX20221101                                       0
#             FX20221104                                       0
#             FX20221201                                       0
#             FX20221202                                       0
# ...                                                        ...
# Hailong3    GJ24050528                                       0
#             GJ24050529                                       0
#             GJ24050530                                       0
#             GJ24050531                                       0
#             GJ24050532                                       0
#
#                                 Cr_10000051 Time Deposit - USD  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                       0
#             FX20221101                                       0
#             FX20221104                                       0
#             FX20221201                                       0
#             FX20221202                                       0
# ...                                                        ...
# Hailong3    GJ24050528                                       0
#             GJ24050529                                       0
#             GJ24050530                                       0
#             GJ24050531                                       0
#             GJ24050532                                       0
#
#                                 Cr_10000052 Time Deposit - EUR  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                       0
#             FX20221101                                       0
#             FX20221104                                       0
#             FX20221201                                       0
#             FX20221202                                       0
# ...                                                        ...
# Hailong3    GJ24050528                                       0
#             GJ24050529                                       0
#             GJ24050530                                       0
#             GJ24050531                                       0
#             GJ24050532                                       0
#
#                                 Cr_10010001 Restricted Cash - Time Deposit(NTD)  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                        0
#             FX20221101                                                        0
#             FX20221104                                                        0
#             FX20221201                                                        0
#             FX20221202                                                        0
# ...                                                                         ...
# Hailong3    GJ24050528                                                        0
#             GJ24050529                                                        0
#             GJ24050530                                                        0
#             GJ24050531                                                        0
#             GJ24050532                                                        0
#
#                                 Cr_10010001 Restricted Cash - Time Deposit(TWD)  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                        0
#             FX20221101                                                        0
#             FX20221104                                                        0
#             FX20221201                                                        0
#             FX20221202                                                        0
# ...                                                                         ...
# Hailong3    GJ24050528                                                        0
#             GJ24050529                                                        0
#             GJ24050530                                                        0
#             GJ24050531                                                        0
#             GJ24050532                                                        0
#
#                                 Cr_10010010 Restricted Cash - Time Deposit(EUR)  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                        0
#             FX20221101                                                        0
#             FX20221104                                                        0
#             FX20221201                                                        0
#             FX20221202                                                        0
# ...                                                                         ...
# Hailong3    GJ24050528                                                        0
#             GJ24050529                                                        0
#             GJ24050530                                                        0
#             GJ24050531                                                        0
#             GJ24050532                                                        0
#
#                                 ...  Zero_60250000 Bank Charges  \
# CompanyName DocumentNo_GLEntry  ...
# Hailong2    EX20221025          ...                           0
#             FX20221101          ...                           0
#             FX20221104          ...                           0
#             FX20221201          ...                           0
#             FX20221202          ...                           0
# ...                             ...                         ...
# Hailong3    GJ24050528          ...                           0
#             GJ24050529          ...                           0
#             GJ24050530          ...                           0
#             GJ24050531          ...                           0
#             GJ24050532          ...                           0
#
#                                 Zero_60325000 Interest Income  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                      0
#             FX20221101                                      0
#             FX20221104                                      0
#             FX20221201                                      0
#             FX20221202                                      0
# ...                                                       ...
# Hailong3    GJ24050528                                      0
#             GJ24050529                                      0
#             GJ24050530                                      0
#             GJ24050531                                      0
#             GJ24050532                                      0
#
#                                 Zero_60900100 Cost Sharing - HL3  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                         0
#             FX20221101                                         0
#             FX20221104                                         0
#             FX20221201                                         0
#             FX20221202                                         0
# ...                                                          ...
# Hailong3    GJ24050528                                         0
#             GJ24050529                                         0
#             GJ24050530                                         0
#             GJ24050531                                         0
#             GJ24050532                                         0
#
#                                 Zero_60900200 Cost Capatalization  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                          0
#             FX20221101                                          0
#             FX20221104                                          0
#             FX20221201                                          0
#             FX20221202                                          0
# ...                                                           ...
# Hailong3    GJ24050528                                          0
#             GJ24050529                                          0
#             GJ24050530                                          0
#             GJ24050531                                          0
#             GJ24050532                                          0
#
#                                 Zero_70010000 Foreign Exchange Gain/Loss  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                 0
#             FX20221101                                                 0
#             FX20221104                                                 0
#             FX20221201                                                 0
#             FX20221202                                                 0
# ...                                                                  ...
# Hailong3    GJ24050528                                                 0
#             GJ24050529                                                 0
#             GJ24050530                                                 0
#             GJ24050531                                                 0
#             GJ24050532                                                 0
#
#                                 Zero_70010100 Unrealized Exchange Gain/Loss  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                    0
#             FX20221101                                                    0
#             FX20221104                                                    0
#             FX20221201                                                    0
#             FX20221202                                                    0
# ...                                                                     ...
# Hailong3    GJ24050528                                                    0
#             GJ24050529                                                    0
#             GJ24050530                                                    0
#             GJ24050531                                                    0
#             GJ24050532                                                    0
#
#                                 Zero_70100000 Gain/Loss on Sale of Assets  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                                  0
#             FX20221101                                                  0
#             FX20221104                                                  0
#             FX20221201                                                  0
#             FX20221202                                                  0
# ...                                                                   ...
# Hailong3    GJ24050528                                                  0
#             GJ24050529                                                  0
#             GJ24050530                                                  0
#             GJ24050531                                                  0
#             GJ24050532                                                  0
#
#                                 Zero_80100000 Income Taxes - Deferred  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                                              0
#             FX20221101                                              0
#             FX20221104                                              0
#             FX20221201                                              0
#             FX20221202                                              0
# ...                                                               ...
# Hailong3    GJ24050528                                              0
#             GJ24050529                                              0
#             GJ24050530                                              0
#             GJ24050531                                              0
#             GJ24050532                                              0
#
#                                                                 Cluster_Signature  \
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025          Cr_70010000 Foreign Exchange Gain/Loss, Dr_100...
#             FX20221101          Cr_10000020 Cash on Hands - EUR, Cr_70010000 F...
#             FX20221104          Cr_10000010 Cash on Hands - USD, Cr_70010000 F...
#             FX20221201          Cr_70010000 Foreign Exchange Gain/Loss, Dr_100...
#             FX20221202          Cr_10000010 Cash on Hands - USD, Cr_70010000 F...
# ...                                                                           ...
# Hailong3    GJ24050528          Cr_16100000 Construction in Progress, Dr_2002Y...
#             GJ24050529          Cr_14020000 Derivative Asset - Current, Cr_304...
#             GJ24050530          Cr_20800000 Deferred Tax Liabilities, Cr_30400...
#             GJ24050531          Cr_2060EDBS Bank Loan - EBL DBS, Cr_2060EMUFG ...
#             GJ24050532          Cr_20800000 Deferred Tax Liabilities, Dr_80100...
#
#                                 Cluster_ID
# CompanyName DocumentNo_GLEntry
# Hailong2    EX20221025                 723
#             FX20221101                 117
#             FX20221104                  75
#             FX20221201                 723
#             FX20221202                  75
# ...                                    ...
# Hailong3    GJ24050528                 276
#             GJ24050529                 238
#             GJ24050530                 651
#             GJ24050531                 625
#             GJ24050532                 655
#
# [16956 rows x 243 columns]

# %%
# Get cluster signature, cluster id and population map
cluster_id_to_signature = pivot_binary.copy()
cluster_id_to_signature = cluster_id_to_signature[['Cluster_ID', 'Cluster_Signature']].drop_duplicates()

cluster_counts = pivot_binary['Cluster_ID'].value_counts().sort_index()
cluster_id_to_signature['Population'] = cluster_id_to_signature['Cluster_ID'].map(cluster_counts)

cluster_map = dict(zip(cluster_id_to_signature['Cluster_ID'], 
                       zip(cluster_id_to_signature['Cluster_Signature'],
                       cluster_id_to_signature['Population'])))

cluster_map
# Out:
# {723: ('Cr_70010000 Foreign Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR',
#   5),
#  117: ('Cr_10000020 Cash on Hands - EUR, Cr_70010000 Foreign Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  75: ('Cr_10000010 Cash on Hands - USD, Cr_70010000 Foreign Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_70010000 Foreign Exchange Gain/Loss',
#   2),
#  360: ('Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_10000020 Cash on Hands - EUR, Dr_20000000 AP - Trade, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  88: ('Cr_10000010 Cash on Hands - USD, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  55: ('Cr_10000010 Cash on Hands - USD, Cr_10000020 Cash on Hands - EUR, Cr_20000000 AP - Trade, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  343: ('Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_10000020 Cash on Hands - EUR, Dr_20000000 AP - Trade, Dr_70010100 Unrealized Exchange Gain/Loss',
#   2),
#  56: ('Cr_10000010 Cash on Hands - USD, Cr_10000051 Time Deposit - USD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR, Dr_10000052 Time Deposit - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_20000000 AP - Trade, Dr_20020000 AP - Intercompany, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  51: ('Cr_10000010 Cash on Hands - USD, Cr_10000020 Cash on Hands - EUR, Cr_10010010 Restricted Cash - Time Deposit(EUR), Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_2002HLHTW Inter AP - HLH TW, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_10000020 Cash on Hands - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  340: ('Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_2002HLHTW Inter AP - HLH TW, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_10000020 Cash on Hands - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_20000000 AP - Trade, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  338: ('Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_20020HL3 Inter AP - HL3, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_20000000 AP - Trade, Dr_2002HLHTW Inter AP - HLH TW, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  339: ('Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_20020HL3 Inter AP - HL3, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_20000000 AP - Trade, Dr_20080000 Withholding Tax Payable, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  160: ('Cr_10000052 Time Deposit - EUR, Cr_10010010 Restricted Cash - Time Deposit(EUR), Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_2002HLHTW Inter AP - HLH TW, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR, Dr_20000000 AP - Trade, Dr_20020HL3 Inter AP - HL3, Dr_20080000 Withholding Tax Payable, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  61: ('Cr_10000010 Cash on Hands - USD, Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_20020HL3 Inter AP - HL3, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR, Dr_10000052 Time Deposit - EUR, Dr_11020HL3 Inter AR - HL3, Dr_11020MIT Inter AR - Mitsui, Dr_20000000 AP - Trade, Dr_2002HLHTW Inter AP - HLH TW, Dr_20080000 Withholding Tax Payable, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  50: ('Cr_10000010 Cash on Hands - USD, Cr_10000020 Cash on Hands - EUR, Cr_10010010 Restricted Cash - Time Deposit(EUR), Cr_11020HL3 Inter AR - HL3, Cr_11020MIT Inter AR - Mitsui, Cr_20000000 AP - Trade, Cr_2002HLHBV Inter AP - HLH BV, Cr_2002HLHTW Inter AP - HLH TW, Cr_20080000 Withholding Tax Payable, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_20020000 AP - Intercompany, Dr_20020HL3 Inter AP - HL3, Dr_2002HLHBV Inter AP - HLH BV, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  91: ('Cr_10000020 Cash on Hands - EUR, Cr_10010010 Restricted Cash - Time Deposit(EUR), Cr_11020HL3 Inter AR - HL3, Cr_11020MIT Inter AR - Mitsui, Cr_20000000 AP - Trade, Cr_2002HLHBV Inter AP - HLH BV, Cr_2002HLHTW Inter AP - HLH TW, Cr_20080000 Withholding Tax Payable, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_11020HL3 Inter AR - HL3, Dr_20000000 AP - Trade, Dr_20020000 AP - Intercompany, Dr_20020HL3 Inter AP - HL3, Dr_2002HLHBV Inter AP - HLH BV, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  93: ('Cr_10000020 Cash on Hands - EUR, Cr_11020MIT Inter AR - Mitsui, Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_20020HL3 Inter AP - HL3, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_10000020 Cash on Hands - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_11020HL3 Inter AR - HL3, Dr_11020MIT Inter AR - Mitsui, Dr_20000000 AP - Trade, Dr_20020HL3 Inter AP - HL3, Dr_2002HLHTW Inter AP - HLH TW, Dr_20080000 Withholding Tax Payable, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  60: ('Cr_10000010 Cash on Hands - USD, Cr_11020MIT Inter AR - Mitsui, Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_20020HL3 Inter AP - HL3, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_11020HL3 Inter AR - HL3, Dr_11020MIT Inter AR - Mitsui, Dr_20000000 AP - Trade, Dr_2002HLHTW Inter AP - HLH TW, Dr_20080000 Withholding Tax Payable, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  198: ('Cr_11020HL3 Inter AR - HL3, Cr_11020MIT Inter AR - Mitsui, Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_20020HL3 Inter AP - HL3, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_10000020 Cash on Hands - EUR, Dr_10000045 Cash on Hands - JPY, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_11020HL3 Inter AR - HL3, Dr_11020MIT Inter AR - Mitsui, Dr_20000000 AP - Trade, Dr_2002HLHBV Inter AP - HLH BV, Dr_2002HLHTW Inter AP - HLH TW, Dr_20080000 Withholding Tax Payable, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  90: ('Cr_10000020 Cash on Hands - EUR, Cr_10000045 Cash on Hands - JPY, Cr_11020HL3 Inter AR - HL3, Cr_11020MIT Inter AR - Mitsui, Cr_20000000 AP - Trade, Cr_20020000 AP - Intercompany, Cr_20020HL3 Inter AP - HL3, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD, Dr_10000020 Cash on Hands - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_11020HL3 Inter AR - HL3, Dr_11020MIT Inter AR - Mitsui, Dr_20000000 AP - Trade, Dr_2002HLHTW Inter AP - HLH TW, Dr_20080000 Withholding Tax Payable, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  58: ('Cr_10000010 Cash on Hands - USD, Cr_11020HL3 Inter AR - HL3, Cr_20000000 AP - Trade, Cr_20020HL3 Inter AP - HL3, Cr_2002HLHTW Inter AP - HLH TW, Cr_20080000 Withholding Tax Payable, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_10000020 Cash on Hands - EUR, Dr_10000045 Cash on Hands - JPY, Dr_10010010 Restricted Cash - Time Deposit(EUR), Dr_20000000 AP - Trade, Dr_2002HLHTW Inter AP - HLH TW, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  660: ('Cr_30000000 Common Shares - Intercompany, Dr_10000000 Cash on Hands - TWD',
#   11),
#  392: ('Cr_20000000 AP - Trade, Dr_16100000 Construction in Progress', 1993),
#  381: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress',
#   2028),
#  309: ('Cr_16100001 Construction in Progress - proxy for cost control, Dr_16100000 Construction in Progress',
#   415),
#  213: ('Cr_11080000 Input VAT, Cr_16100000 Construction in Progress, Dr_20000000 AP - Trade',
#   18),
#  600: ('Cr_20080000 Withholding Tax Payable, Cr_20080010 Hithhold - 2nd Gen. NHI, Dr_20000000 AP - Trade',
#   54),
#  312: ('Cr_16100001 Construction in Progress - proxy for cost control, Dr_20000000 AP - Trade',
#   380),
#  390: ('Cr_20000000 AP - Trade, Dr_12020000 Prepaid - Others', 47),
#  270: ('Cr_16100000 Construction in Progress, Dr_20000000 AP - Trade', 33),
#  657: ('Cr_20900000 Retention Payable, Dr_20000000 AP - Trade', 2),
#  33: ('Cr_10000000 Cash on Hands - TWD, Dr_20000000 AP - Trade', 2034),
#  17: ('Cr_10000000 Cash on Hands - TWD, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade',
#   24),
#  118: ('Cr_10000020 Cash on Hands - EUR, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade',
#   132),
#  47: ('Cr_10000000 Cash on Hands - TWD, Dr_60250000 Bank Charges', 90),
#  0: ('', 18),
#  485: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other',
#   57),
#  478: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other',
#   63),
#  477: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal',
#   155),
#  444: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress', 148),
#  475: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation', 380),
#  520: ('Cr_20010010 AP - Employee, Dr_60040120 Entertainment', 92),
#  445: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation',
#   64),
#  484: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal',
#   203),
#  380: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT', 5),
#  603: ('Cr_20080000 Withholding Tax Payable, Dr_20000000 AP - Trade', 1074),
#  34: ('Cr_10000000 Cash on Hands - TWD, Dr_20000000 AP - Trade, Dr_20010010 AP - Employee',
#   2),
#  21: ('Cr_10000000 Cash on Hands - TWD, Dr_10000010 Cash on Hands - USD', 26),
#  22: ('Cr_10000000 Cash on Hands - TWD, Dr_10000020 Cash on Hands - EUR', 22),
#  77: ('Cr_10000010 Cash on Hands - USD, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   2),
#  19: ('Cr_10000000 Cash on Hands - TWD, Dr_10000000 Cash on Hands - TWD', 42),
#  704: ('Cr_60250000 Bank Charges, Dr_10000000 Cash on Hands - TWD', 5),
#  440: ('Cr_20010010 AP - Employee, Dr_10000000 Cash on Hands - TWD', 3),
#  230: ('Cr_12020000 Prepaid - Others, Dr_20000000 AP - Trade', 3),
#  623: ('Cr_20400000 Other Labilities, Dr_10000020 Cash on Hands - EUR, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  124: ('Cr_10000020 Cash on Hands - EUR, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20400000 Other Labilities',
#   1),
#  376: ('Cr_20000000 AP - Trade, Dr_10000020 Cash on Hands - EUR, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  87: ('Cr_10000010 Cash on Hands - USD, Dr_20400000 Other Labilities, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  271: ('Cr_16100000 Construction in Progress, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  608: ('Cr_20120000 Accrued Liabilities, Dr_16100000 Construction in Progress',
#   79),
#  306: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20900000 Retention Payable, Dr_20000000 AP - Trade',
#   4),
#  315: ('Cr_16100001 Construction in Progress - proxy for cost control, Dr_20120000 Accrued Liabilities',
#   24),
#  713: ('Cr_60900100 Cost Sharing - HL3, Dr_11020001 Accounts Receviable - Intercompany',
#   11),
#  322: ('Cr_16100020 Construction in Progress - PL capitalization, Dr_60900200 Cost Capatalization',
#   6),
#  313: ('Cr_16100001 Construction in Progress - proxy for cost control, Dr_20010010 AP - Employee',
#   11),
#  299: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20080000 Withholding Tax Payable, Dr_20000000 AP - Trade',
#   2),
#  476: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel',
#   114),
#  42: ('Cr_10000000 Cash on Hands - TWD, Dr_20080000 Withholding Tax Payable',
#   222),
#  38: ('Cr_10000000 Cash on Hands - TWD, Dr_20010010 AP - Employee', 1187),
#  13: ('Cr_10000000 Cash on Hands - TWD, Cr_60250000 Bank Charges, Dr_10000000 Cash on Hands - TWD, Dr_60250000 Bank Charges',
#   2),
#  141: ('Cr_10000020 Cash on Hands - EUR, Dr_20000000 AP - Trade', 84),
#  85: ('Cr_10000010 Cash on Hands - USD, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   5),
#  405: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation', 26),
#  411: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel',
#   16),
#  441: ('Cr_20010010 AP - Employee, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress',
#   3),
#  367: ('Cr_20000000 AP - Trade, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  44: ('Cr_10000000 Cash on Hands - TWD, Dr_20080010 Hithhold - 2nd Gen. NHI',
#   17),
#  15: ('Cr_10000000 Cash on Hands - TWD, Cr_60250000 Bank Charges, Dr_60250000 Bank Charges',
#   3),
#  20: ('Cr_10000000 Cash on Hands - TWD, Dr_10000000 Cash on Hands - TWD, Dr_60250000 Bank Charges',
#   26),
#  374: ('Cr_20000000 AP - Trade, Dr_10000020 Cash on Hands - EUR', 3),
#  610: ('Cr_20120000 Accrued Liabilities, Dr_16100001 Construction in Progress - proxy for cost control',
#   17),
#  726: ('Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade', 7),
#  398: ('Cr_20000000 AP - Trade, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   3),
#  250: ('Cr_16100000 Construction in Progress, Cr_20120000 Accrued Liabilities, Dr_16100000 Construction in Progress, Dr_20120000 Accrued Liabilities',
#   2),
#  304: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20120000 Accrued Liabilities, Dr_16100001 Construction in Progress - proxy for cost control, Dr_20120000 Accrued Liabilities',
#   1),
#  301: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20120000 Accrued Liabilities, Dr_16100000 Construction in Progress, Dr_20120000 Accrued Liabilities',
#   21),
#  735: ('Cr_80100000 Income Taxes - Deferred, Dr_19000000 Deferred Tax Assets',
#   7),
#  220: ('Cr_11080000 Input VAT, Dr_20000000 AP - Trade', 5),
#  391: ('Cr_20000000 AP - Trade, Dr_12030000 Deposit', 11),
#  462: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040120 Entertainment',
#   13),
#  494: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040120 Entertainment',
#   32),
#  472: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040120 Entertainment',
#   11),
#  442: ('Cr_20010010 AP - Employee, Dr_12020000 Prepaid - Others', 1),
#  98: ('Cr_10000020 Cash on Hands - EUR, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   151),
#  66: ('Cr_10000010 Cash on Hands - USD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   223),
#  70: ('Cr_10000010 Cash on Hands - USD, Cr_20000000 AP - Trade, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   173),
#  5: ('Cr_10000000 Cash on Hands - TWD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   75),
#  49: ('Cr_10000000 Cash on Hands - TWD, Dr_70010000 Foreign Exchange Gain/Loss',
#   3),
#  422: ('Cr_20000000 AP - Trade, Dr_60040040 Travel - Hotel', 33),
#  430: ('Cr_20000000 AP - Trade, Dr_60250000 Bank Charges', 15),
#  487: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040120 Entertainment',
#   22),
#  546: ('Cr_20020000 AP - Intercompany, Dr_16100010 DEVEX - Open Balance', 6),
#  278: ('Cr_16100000 Construction in Progress, Dr_20120000 Accrued Liabilities',
#   44),
#  715: ('Cr_60900200 Cost Capatalization, Dr_16100020 Construction in Progress - PL capitalization',
#   12),
#  333: ('Cr_19000000 Deferred Tax Assets, Cr_20800000 Deferred Tax Liabilities, Dr_80100000 Income Taxes - Deferred',
#   4),
#  516: ('Cr_20010010 AP - Employee, Dr_60040060 Travel - Other', 11),
#  481: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040060 Travel - Other',
#   8),
#  414: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other',
#   1),
#  397: ('Cr_20000000 AP - Trade, Dr_20000000 AP - Trade', 52),
#  416: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal',
#   4),
#  369: ('Cr_20000000 AP - Trade, Dr_10000000 Cash on Hands - TWD', 14),
#  490: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040060 Travel - Other',
#   50),
#  453: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal',
#   30),
#  480: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_60040120 Entertainment',
#   21),
#  448: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other',
#   7),
#  534: ('Cr_20020000 AP - Intercompany, Cr_30000000 Common Shares - Intercompany, Dr_10000020 Cash on Hands - EUR',
#   4),
#  142: ('Cr_10000020 Cash on Hands - EUR, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   74),
#  251: ('Cr_16100000 Construction in Progress, Cr_20120000 Accrued Liabilities, Dr_16100001 Construction in Progress - proxy for cost control, Dr_20120000 Accrued Liabilities',
#   8),
#  527: ('Cr_20020000 AP - Intercompany, Cr_20080000 Withholding Tax Payable, Dr_16100010 DEVEX - Open Balance',
#   5),
#  226: ('Cr_12020000 Prepaid - Others, Cr_16100001 Construction in Progress - proxy for cost control, Dr_16100000 Construction in Progress',
#   1),
#  620: ('Cr_20400000 Other Labilities, Dr_10000010 Cash on Hands - USD', 3),
#  736: ('Cr_80100000 Income Taxes - Deferred, Dr_19000000 Deferred Tax Assets, Dr_20800000 Deferred Tax Liabilities',
#   2),
#  323: ('Cr_16100020 Construction in Progress - PL capitalization, Dr_70010000 Foreign Exchange Gain/Loss',
#   2),
#  725: ('Cr_70010000 Foreign Exchange Gain/Loss, Dr_16100020 Construction in Progress - PL capitalization',
#   2),
#  335: ('Cr_19000000 Deferred Tax Assets, Dr_80100000 Income Taxes - Deferred',
#   3),
#  676: ('Cr_30020000 Contributed Surplus, Dr_10000000 Cash on Hands - TWD', 1),
#  659: ('Cr_30000000 Common Shares - Intercompany, Cr_30020000 Contributed Surplus, Dr_20400000 Other Labilities',
#   1),
#  470: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040060 Travel - Other',
#   2),
#  425: ('Cr_20000000 AP - Trade, Dr_60040120 Entertainment', 16),
#  447: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal',
#   11),
#  449: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_60040120 Entertainment',
#   6),
#  418: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040120 Entertainment',
#   1),
#  471: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040101 Company Event - External',
#   1),
#  658: ('Cr_30000000 Common Shares - Intercompany, Cr_30020000 Contributed Surplus, Dr_10000000 Cash on Hands - TWD',
#   1),
#  435: ('Cr_20010000 AP - Others, Dr_11000100 AR - Others', 9),
#  619: ('Cr_20400000 Other Labilities, Dr_10000000 Cash on Hands - TWD', 13),
#  664: ('Cr_30000000 Common Shares - Intercompany, Dr_20400000 Other Labilities',
#   4),
#  86: ('Cr_10000010 Cash on Hands - USD, Dr_20020000 AP - Intercompany', 1),
#  375: ('Cr_20000000 AP - Trade, Dr_10000020 Cash on Hands - EUR, Dr_60250000 Bank Charges',
#   2),
#  456: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040120 Entertainment',
#   9),
#  128: ('Cr_10000020 Cash on Hands - EUR, Dr_10000010 Cash on Hands - USD', 63),
#  84: ('Cr_10000010 Cash on Hands - USD, Dr_20000000 AP - Trade', 129),
#  76: ('Cr_10000010 Cash on Hands - USD, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade',
#   112),
#  622: ('Cr_20400000 Other Labilities, Dr_10000020 Cash on Hands - EUR, Dr_60250000 Bank Charges',
#   3),
#  147: ('Cr_10000020 Cash on Hands - EUR, Dr_20400000 Other Labilities', 4),
#  145: ('Cr_10000020 Cash on Hands - EUR, Dr_20020000 AP - Intercompany', 4),
#  262: ('Cr_16100000 Construction in Progress, Dr_16100000 Construction in Progress',
#   1),
#  292: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20020000 AP - Intercompany, Dr_16100000 Construction in Progress',
#   14),
#  613: ('Cr_20120000 Accrued Liabilities, Dr_60100000 Professional Fees', 50),
#  300: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20120000 Accrued Liabilities, Dr_16100000 Construction in Progress',
#   4),
#  219: ('Cr_11080000 Input VAT, Dr_16100000 Construction in Progress', 2),
#  402: ('Cr_20000000 AP - Trade, Dr_20080000 Withholding Tax Payable', 7),
#  26: ('Cr_10000000 Cash on Hands - TWD, Dr_11020001 Accounts Receviable - Intercompany',
#   18),
#  36: ('Cr_10000000 Cash on Hands - TWD, Dr_20010000 AP - Others', 2),
#  621: ('Cr_20400000 Other Labilities, Dr_10000020 Cash on Hands - EUR', 4),
#  30: ('Cr_10000000 Cash on Hands - TWD, Dr_12020010 Income Tax Receivable', 3),
#  705: ('Cr_60325000 Interest Income, Dr_10000000 Cash on Hands - TWD', 8),
#  686: ('Cr_60040030 Travel - Transportation, Dr_60040035 Travel - Transportation(expense)',
#   1),
#  690: ('Cr_60040060 Travel - Other, Dr_60040065 Travel - Other(expense)', 1),
#  280: ('Cr_16100000 Construction in Progress, Dr_60040101 Company Event - External, Dr_60040102 Company Event - Internal',
#   2),
#  281: ('Cr_16100000 Construction in Progress, Dr_60040180 Training', 2),
#  692: ('Cr_60040101 Company Event - External, Dr_16100000 Construction in Progress, Dr_60040102 Company Event - Internal',
#   1),
#  731: ('Cr_70010100 Unrealized Exchange Gain/Loss, Dr_70010000 Foreign Exchange Gain/Loss',
#   2),
#  458: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040060 Travel - Other',
#   2),
#  394: ('Cr_20000000 AP - Trade, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040101 Company Event - External, Dr_60040120 Entertainment',
#   1),
#  496: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense)',
#   25),
#  464: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense)',
#   15),
#  386: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040101 Company Event - External',
#   49),
#  424: ('Cr_20000000 AP - Trade, Dr_60040101 Company Event - External', 17),
#  693: ('Cr_60040101 Company Event - External, Dr_20000000 AP - Trade', 6),
#  497: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense)',
#   7),
#  506: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040120 Entertainment',
#   6),
#  426: ('Cr_20000000 AP - Trade, Dr_60040160 Employee Benefit', 1),
#  602: ('Cr_20080000 Withholding Tax Payable, Dr_16100000 Construction in Progress',
#   10),
#  45: ('Cr_10000000 Cash on Hands - TWD, Dr_20400000 Other Labilities', 3),
#  362: ('Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_16100000 Construction in Progress, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  521: ('Cr_20010010 AP - Employee, Dr_60040180 Training', 27),
#  6: ('Cr_10000000 Cash on Hands - TWD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   3),
#  95: ('Cr_10000020 Cash on Hands - EUR, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  96: ('Cr_10000020 Cash on Hands - EUR, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   19),
#  258: ('Cr_16100000 Construction in Progress, Dr_11080000 Input VAT', 8),
#  431: ('Cr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss', 6),
#  433: ('Cr_20000010 Notes Payable, Dr_20000000 AP - Trade', 2),
#  396: ('Cr_20000000 AP - Trade, Dr_16100001 Construction in Progress - proxy for cost control',
#   5),
#  539: ('Cr_20020000 AP - Intercompany, Dr_16100000 Construction in Progress',
#   35),
#  289: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20000000 AP - Trade, Dr_16100000 Construction in Progress',
#   636),
#  286: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress',
#   869),
#  532: ('Cr_20020000 AP - Intercompany, Cr_30000000 Common Shares - Intercompany, Dr_10000000 Cash on Hands - TWD, Dr_10000020 Cash on Hands - EUR',
#   2),
#  395: ('Cr_20000000 AP - Trade, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense)',
#   1),
#  486: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other, Dr_60040120 Entertainment',
#   11),
#  491: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040060 Travel - Other, Dr_60040120 Entertainment',
#   11),
#  347: ('Cr_20000000 AP - Trade, Cr_20080010 Hithhold - 2nd Gen. NHI, Dr_20000000 AP - Trade, Dr_20080010 Hithhold - 2nd Gen. NHI',
#   1),
#  607: ('Cr_20080010 Hithhold - 2nd Gen. NHI, Dr_20000000 AP - Trade', 1),
#  135: ('Cr_10000020 Cash on Hands - EUR, Dr_10010001 Restricted Cash - Time Deposit(TWD)',
#   2),
#  101: ('Cr_10000020 Cash on Hands - EUR, Cr_20000000 AP - Trade, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   93),
#  320: ('Cr_16100010 DEVEX - Open Balance, Dr_20020000 AP - Intercompany', 2),
#  538: ('Cr_20020000 AP - Intercompany, Dr_11080000 Input VAT, Dr_16100010 DEVEX - Open Balance',
#   4),
#  427: ('Cr_20000000 AP - Trade, Dr_60040180 Training', 10),
#  530: ('Cr_20020000 AP - Intercompany, Cr_20400000 Other Labilities, Dr_10000000 Cash on Hands - TWD, Dr_10000020 Cash on Hands - EUR',
#   1),
#  624: ('Cr_20400000 Other Labilities, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  166: ('Cr_10010001 Restricted Cash - Time Deposit(TWD), Dr_10000020 Cash on Hands - EUR',
#   1),
#  419: ('Cr_20000000 AP - Trade, Dr_60040035 Travel - Transportation(expense)',
#   4),
#  465: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense)',
#   1),
#  454: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other',
#   5),
#  517: ('Cr_20010010 AP - Employee, Dr_60040101 Company Event - External', 4),
#  501: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040065 Travel - Other(expense), Dr_60040120 Entertainment',
#   1),
#  514: ('Cr_20010010 AP - Employee, Dr_60040055 Travel - Meal(expense)', 4),
#  354: ('Cr_20000000 AP - Trade, Cr_60040101 Company Event - External, Dr_60040101 Company Event - External',
#   9),
#  513: ('Cr_20010010 AP - Employee, Dr_60040050 Travel - Meal, Dr_60040120 Entertainment',
#   2),
#  504: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040055 Travel - Meal(expense), Dr_60040120 Entertainment',
#   2),
#  503: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040055 Travel - Meal(expense)',
#   3),
#  450: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_60040180 Training',
#   2),
#  533: ('Cr_20020000 AP - Intercompany, Cr_30000000 Common Shares - Intercompany, Dr_10000010 Cash on Hands - USD',
#   2),
#  523: ('Cr_20020000 AP - Intercompany, Cr_2002NPIHQ Inter AP - NPI HQ, Cr_30000000 Common Shares - Intercompany, Dr_20020000 AP - Intercompany',
#   1),
#  524: ('Cr_20020000 AP - Intercompany, Cr_2002YECL Inter AP - YECL, Dr_20020000 AP - Intercompany',
#   1),
#  311: ('Cr_16100001 Construction in Progress - proxy for cost control, Dr_16100001 Construction in Progress - proxy for cost control',
#   3),
#  25: ('Cr_10000000 Cash on Hands - TWD, Dr_10020001 Petty Cash', 7),
#  709: ('Cr_60325000 Interest Income, Dr_10000020 Cash on Hands - EUR', 9),
#  120: ('Cr_10000020 Cash on Hands - EUR, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20020000 AP - Intercompany',
#   2),
#  35: ('Cr_10000000 Cash on Hands - TWD, Dr_20000010 Notes Payable', 34),
#  8: ('Cr_10000000 Cash on Hands - TWD, Cr_20000000 AP - Trade, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   59),
#  72: ('Cr_10000010 Cash on Hands - USD, Cr_20020000 AP - Intercompany, Dr_20020000 AP - Intercompany, Dr_70010000 Foreign Exchange Gain/Loss',
#   2),
#  263: ('Cr_16100000 Construction in Progress, Dr_16100001 Construction in Progress - proxy for cost control',
#   10),
#  305: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20900000 Retention Payable, Dr_16100000 Construction in Progress',
#   2),
#  473: ('Cr_20010010 AP - Employee, Dr_20000000 AP - Trade', 2),
#  190: ('Cr_11020001 Accounts Receviable - Intercompany, Dr_60900100 Cost Sharing - HL3',
#   2),
#  423: ('Cr_20000000 AP - Trade, Dr_60040040 Travel - Hotel, Dr_60040045 Travel - Hotel(expense)',
#   2),
#  688: ('Cr_60040040 Travel - Hotel, Cr_60040045 Travel - Hotel(expense), Dr_20000000 AP - Trade',
#   1),
#  515: ('Cr_20010010 AP - Employee, Dr_60040055 Travel - Meal(expense), Dr_60040120 Entertainment',
#   1),
#  467: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040055 Travel - Meal(expense)',
#   1),
#  459: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040060 Travel - Other, Dr_60040101 Company Event - External, Dr_60040120 Entertainment',
#   1),
#  455: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other, Dr_60040120 Entertainment',
#   2),
#  290: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress',
#   11),
#  48: ('Cr_10000000 Cash on Hands - TWD, Dr_60325000 Interest Income', 1),
#  482: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040120 Entertainment',
#   8),
#  500: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040120 Entertainment',
#   2),
#  353: ('Cr_20000000 AP - Trade, Cr_60040101 Company Event - External, Dr_11080000 Input VAT, Dr_60040101 Company Event - External',
#   29),
#  359: ('Cr_20000000 AP - Trade, Cr_60100000 Professional Fees, Dr_60100000 Professional Fees',
#   4),
#  406: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040035 Travel - Transportation(expense)',
#   3),
#  420: ('Cr_20000000 AP - Trade, Dr_60040035 Travel - Transportation(expense), Dr_60040040 Travel - Hotel',
#   1),
#  685: ('Cr_60040030 Travel - Transportation, Dr_20010010 AP - Employee', 2),
#  136: ('Cr_10000020 Cash on Hands - EUR, Dr_10010010 Restricted Cash - Time Deposit(EUR)',
#   4),
#  81: ('Cr_10000010 Cash on Hands - USD, Dr_10010020 Restricted Cash - Time Deposit(USD)',
#   4),
#  24: ('Cr_10000000 Cash on Hands - TWD, Dr_10010001 Restricted Cash - Time Deposit(TWD)',
#   1),
#  37: ('Cr_10000000 Cash on Hands - TWD, Dr_20010000 AP - Others, Dr_20080010 Hithhold - 2nd Gen. NHI',
#   5),
#  172: ('Cr_10010010 Restricted Cash - Time Deposit(EUR), Dr_10000020 Cash on Hands - EUR',
#   2),
#  707: ('Cr_60325000 Interest Income, Dr_10000010 Cash on Hands - USD', 4),
#  175: ('Cr_10010020 Restricted Cash - Time Deposit(USD), Dr_10000010 Cash on Hands - USD',
#   2),
#  168: ('Cr_10010001 Restricted Cash - Time Deposit(TWD), Dr_10010010 Restricted Cash - Time Deposit(EUR)',
#   1),
#  173: ('Cr_10010010 Restricted Cash - Time Deposit(EUR), Dr_10000052 Time Deposit - EUR',
#   2),
#  167: ('Cr_10010001 Restricted Cash - Time Deposit(TWD), Dr_10000050 Time Deposit - TWD',
#   1),
#  176: ('Cr_10010020 Restricted Cash - Time Deposit(USD), Dr_10000051 Time Deposit - USD',
#   2),
#  169: ('Cr_10010001 Restricted Cash - Time Deposit(TWD), Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  711: ('Cr_60325000 Interest Income, Dr_12020010 Income Tax Receivable', 4),
#  612: ('Cr_20120000 Accrued Liabilities, Dr_20120000 Accrued Liabilities', 1),
#  302: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20120000 Accrued Liabilities, Dr_16100000 Construction in Progress, Dr_20120000 Accrued Liabilities, Dr_60100000 Professional Fees',
#   1),
#  307: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_60100000 Professional Fees, Dr_16100000 Construction in Progress, Dr_20120000 Accrued Liabilities',
#   1),
#  174: ('Cr_10010010 Restricted Cash - Time Deposit(EUR), Dr_10010010 Restricted Cash - Time Deposit(EUR)',
#   2),
#  162: ('Cr_10000052 Time Deposit - EUR, Dr_10000052 Time Deposit - EUR', 2),
#  159: ('Cr_10000051 Time Deposit - USD, Dr_10000051 Time Deposit - USD', 2),
#  655: ('Cr_20800000 Deferred Tax Liabilities, Dr_80100000 Income Taxes - Deferred',
#   24),
#  460: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040060 Travel - Other, Dr_60040120 Entertainment',
#   4),
#  382: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040030 Travel - Transportation',
#   9),
#  438: ('Cr_20010010 AP - Employee, Cr_60040030 Travel - Transportation, Dr_60040030 Travel - Transportation',
#   11),
#  687: ('Cr_60040035 Travel - Transportation(expense), Dr_20000000 AP - Trade',
#   5),
#  212: ('Cr_11080000 Input VAT, Cr_16100000 Construction in Progress, Dr_16100001 Construction in Progress - proxy for cost control, Dr_20000000 AP - Trade',
#   10),
#  158: ('Cr_10000051 Time Deposit - USD, Dr_10000010 Cash on Hands - USD', 2),
#  708: ('Cr_60325000 Interest Income, Dr_10000010 Cash on Hands - USD, Dr_12020010 Income Tax Receivable',
#   2),
#  161: ('Cr_10000052 Time Deposit - EUR, Dr_10000020 Cash on Hands - EUR', 2),
#  710: ('Cr_60325000 Interest Income, Dr_10000020 Cash on Hands - EUR, Dr_12020010 Income Tax Receivable',
#   6),
#  499: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040065 Travel - Other(expense), Dr_60040120 Entertainment',
#   2),
#  529: ('Cr_20020000 AP - Intercompany, Cr_20300000 Debt - Current, Dr_10000000 Cash on Hands - TWD, Dr_10000020 Cash on Hands - EUR',
#   1),
#  663: ('Cr_30000000 Common Shares - Intercompany, Dr_20300000 Debt - Current',
#   1),
#  287: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040101 Company Event - External',
#   1),
#  407: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040035 Travel - Transportation(expense), Dr_60040040 Travel - Hotel',
#   6),
#  408: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040035 Travel - Transportation(expense), Dr_60040040 Travel - Hotel, Dr_60040045 Travel - Hotel(expense)',
#   2),
#  706: ('Cr_60325000 Interest Income, Dr_10000000 Cash on Hands - TWD, Dr_12020010 Income Tax Receivable',
#   2),
#  157: ('Cr_10000050 Time Deposit - TWD, Dr_10000000 Cash on Hands - TWD', 2),
#  140: ('Cr_10000020 Cash on Hands - EUR, Dr_16100000 Construction in Progress',
#   32),
#  432: ('Cr_20000010 Notes Payable, Dr_12020000 Prepaid - Others', 5),
#  150: ('Cr_10000020 Cash on Hands - EUR, Dr_60250000 Bank Charges', 26),
#  115: ('Cr_10000020 Cash on Hands - EUR, Cr_70010000 Foreign Exchange Gain/Loss, Dr_10000010 Cash on Hands - USD',
#   2),
#  436: ('Cr_20010000 AP - Others, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress',
#   39),
#  507: ('Cr_20010010 AP - Employee, Dr_60040040 Travel - Hotel', 6),
#  469: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040055 Travel - Meal(expense), Dr_60040120 Entertainment',
#   2),
#  466: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040120 Entertainment',
#   1),
#  451: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040060 Travel - Other, Dr_60040120 Entertainment',
#   1),
#  388: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040180 Training',
#   14),
#  350: ('Cr_20000000 AP - Trade, Cr_60040035 Travel - Transportation(expense), Dr_11080000 Input VAT, Dr_60040035 Travel - Transportation(expense)',
#   1),
#  356: ('Cr_20000000 AP - Trade, Cr_60040120 Entertainment, Dr_60040120 Entertainment',
#   8),
#  248: ('Cr_16100000 Construction in Progress, Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress',
#   1),
#  357: ('Cr_20000000 AP - Trade, Cr_60040180 Training, Dr_11080000 Input VAT, Dr_60040180 Training',
#   4),
#  127: ('Cr_10000020 Cash on Hands - EUR, Dr_10000000 Cash on Hands - TWD, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  130: ('Cr_10000020 Cash on Hands - EUR, Dr_10000010 Cash on Hands - USD, Dr_70010000 Foreign Exchange Gain/Loss',
#   2),
#  31: ('Cr_10000000 Cash on Hands - TWD, Dr_12030000 Deposit', 3),
#  596: ('Cr_2002YECL Inter AP - YECL, Dr_20020000 AP - Intercompany', 4),
#  701: ('Cr_60040900 Other Operation Cost, Dr_2002YECL Inter AP - YECL', 1),
#  587: ('Cr_2002NPIHQ Inter AP - NPI HQ, Dr_20020000 AP - Intercompany', 1),
#  700: ('Cr_60040900 Other Operation Cost, Dr_2002NPIHQ Inter AP - NPI HQ', 1),
#  592: ('Cr_2002NPITW Inter AP - NPI TW, Dr_20020000 AP - Intercompany', 3),
#  586: ('Cr_2002HLHTW Inter AP - HLH TW, Dr_20020000 AP - Intercompany', 6),
#  358: ('Cr_20000000 AP - Trade, Cr_60040180 Training, Dr_60040180 Training',
#   4),
#  415: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040060 Travel - Other',
#   10),
#  580: ('Cr_2002HLHTW Inter AP - HLH TW, Cr_30000001 Common Shares -  NPI, Dr_10000020 Cash on Hands - EUR',
#   2),
#  668: ('Cr_30000001 Common Shares -  NPI, Dr_20400000 Other Labilities', 1),
#  670: ('Cr_30000002 Common Shares - YECL, Dr_20400000 Other Labilities', 1),
#  106: ('Cr_10000020 Cash on Hands - EUR, Cr_2002HLHTW Inter AP - HLH TW, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20020000 AP - Intercompany, Dr_2002HLHTW Inter AP - HLH TW, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  3: ('Cr_10000000 Cash on Hands - TWD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  185: ('Cr_11020001 Accounts Receviable - Intercompany, Dr_10000000 Cash on Hands - TWD',
#   1),
#  591: ('Cr_2002NPITW Inter AP - NPI TW, Dr_16100000 Construction in Progress',
#   53),
#  314: ('Cr_16100001 Construction in Progress - proxy for cost control, Dr_2002NPITW Inter AP - NPI TW',
#   7),
#  214: ('Cr_11080000 Input VAT, Cr_16100001 Construction in Progress - proxy for cost control, Dr_11020001 Accounts Receviable - Intercompany',
#   1),
#  180: ('Cr_10020001 Petty Cash, Dr_20010000 AP - Others', 3),
#  319: ('Cr_16100010 DEVEX - Open Balance, Dr_16050000 Lease (ROU) Asset - Land',
#   2),
#  617: ('Cr_20390000 Lease Liabilities - Long-term - Land, Dr_16050000 Lease (ROU) Asset - Land',
#   2),
#  316: ('Cr_16100001 Construction in Progress - proxy for cost control, Dr_20390000 Lease Liabilities - Long-term - Land',
#   1),
#  618: ('Cr_20390000 Lease Liabilities - Long-term - Land, Dr_16050010 Lease(ROU) Asset - Interest Capitalization',
#   16),
#  737: ('Cr_80100000 Income Taxes - Deferred, Dr_20800000 Deferred Tax Liabilities',
#   14),
#  550: ('Cr_20020000 AP - Intercompany, Dr_2002HLHTW Inter AP - HLH TW', 2),
#  511: ('Cr_20010010 AP - Employee, Dr_60040050 Travel - Meal', 5),
#  461: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040030 Travel - Transportation, Dr_60040101 Company Event - External, Dr_60040120 Entertainment',
#   1),
#  352: ('Cr_20000000 AP - Trade, Cr_60040100 Advertisement, Dr_11080000 Input VAT, Dr_60040100 Advertisement',
#   3),
#  348: ('Cr_20000000 AP - Trade, Cr_60040030 Travel - Transportation, Dr_11080000 Input VAT, Dr_60040030 Travel - Transportation',
#   1),
#  421: ('Cr_20000000 AP - Trade, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense)',
#   1),
#  502: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040120 Entertainment',
#   1),
#  492: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040101 Company Event - External',
#   2),
#  439: ('Cr_20010010 AP - Employee, Cr_60040102 Company Event - Internal, Dr_60040102 Company Event - Internal',
#   1),
#  666: ('Cr_30000001 Common Shares -  NPI, Cr_30000002 Common Shares - YECL, Cr_30000003 Common Shares - NPDSI, Cr_30000004 Common shares - YEPL, Dr_30000000 Common Shares - Intercompany',
#   1),
#  667: ('Cr_30000001 Common Shares -  NPI, Cr_30000002 Common Shares - YECL, Dr_30000000 Common Shares - Intercompany',
#   8),
#  186: ('Cr_11020001 Accounts Receviable - Intercompany, Dr_11020HL3 Inter AR - HL3',
#   2),
#  505: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040065 Travel - Other(expense)',
#   1),
#  345: ('Cr_20000000 AP - Trade, Cr_20080000 Withholding Tax Payable, Dr_11000100 AR - Others',
#   2),
#  684: ('Cr_60040030 Travel - Transportation, Dr_20000000 AP - Trade', 12),
#  16: ('Cr_10000000 Cash on Hands - TWD, Cr_60325000 Interest Income, Dr_10000000 Cash on Hands - TWD, Dr_12020010 Income Tax Receivable',
#   3),
#  215: ('Cr_11080000 Input VAT, Cr_16100001 Construction in Progress - proxy for cost control, Dr_11020HL3 Inter AR - HL3',
#   2),
#  12: ('Cr_10000000 Cash on Hands - TWD, Cr_20080000 Withholding Tax Payable, Dr_10000000 Cash on Hands - TWD, Dr_20080000 Withholding Tax Payable',
#   1),
#  28: ('Cr_10000000 Cash on Hands - TWD, Dr_11020HL3 Inter AR - HL3', 15),
#  703: ('Cr_60100000 Professional Fees, Dr_20120000 Accrued Liabilities', 5),
#  579: ('Cr_2002HLHTW Inter AP - HLH TW, Cr_2002NPITW Inter AP - NPI TW, Cr_2002YECL Inter AP - YECL, Dr_20020000 AP - Intercompany',
#   1),
#  479: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040040 Travel - Hotel, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other, Dr_60040120 Entertainment',
#   12),
#  417: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040050 Travel - Meal, Dr_60040060 Travel - Other',
#   1),
#  733: ('Cr_70010100 Unrealized Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   2),
#  510: ('Cr_20010010 AP - Employee, Dr_60040040 Travel - Hotel, Dr_60040120 Entertainment',
#   1),
#  509: ('Cr_20010010 AP - Employee, Dr_60040040 Travel - Hotel, Dr_60040060 Travel - Other',
#   1),
#  495: ('Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation, Dr_60040180 Training',
#   5),
#  669: ('Cr_30000002 Common Shares - YECL, Dr_10000000 Cash on Hands - TWD', 1),
#  265: ('Cr_16100000 Construction in Progress, Dr_16100001 Construction in Progress - proxy for cost control, Dr_20000000 AP - Trade',
#   6),
#  468: ('Cr_20010010 AP - Employee, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040120 Entertainment',
#   2),
#  46: ('Cr_10000000 Cash on Hands - TWD, Dr_20400000 Other Labilities, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  65: ('Cr_10000010 Cash on Hands - USD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   16),
#  298: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20080000 Withholding Tax Payable, Dr_16100000 Construction in Progress',
#   3),
#  410: ('Cr_20000000 AP - Trade, Dr_60040030 Travel - Transportation, Dr_60040035 Travel - Transportation(expense), Dr_60040040 Travel - Hotel, Dr_60040060 Travel - Other',
#   2),
#  697: ('Cr_60040120 Entertainment, Dr_20000000 AP - Trade', 1),
#  595: ('Cr_2002YECL Inter AP - YECL, Dr_16100000 Construction in Progress',
#   37),
#  4: ('Cr_10000000 Cash on Hands - TWD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   4),
#  217: ('Cr_11080000 Input VAT, Cr_60040180 Training, Dr_20000000 AP - Trade',
#   1),
#  370: ('Cr_20000000 AP - Trade, Dr_10000000 Cash on Hands - TWD, Dr_60250000 Bank Charges',
#   1),
#  573: ('Cr_20020HL3 Inter AP - HL3, Dr_10000020 Cash on Hands - EUR', 8),
#  108: ('Cr_10000020 Cash on Hands - EUR, Cr_2002HLHTW Inter AP - HLH TW, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_2002HLHTW Inter AP - HLH TW, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  264: ('Cr_16100000 Construction in Progress, Dr_16100001 Construction in Progress - proxy for cost control, Dr_19020000 Other Assets',
#   1),
#  437: ('Cr_20010000 AP - Others, Dr_16100000 Construction in Progress', 3),
#  179: ('Cr_10020001 Petty Cash, Dr_20000000 AP - Trade, Dr_20010000 AP - Others',
#   1),
#  714: ('Cr_60900100 Cost Sharing - HL3, Dr_11020HL3 Inter AR - HL3', 5),
#  261: ('Cr_16100000 Construction in Progress, Dr_12020010 Income Tax Receivable, Dr_16100001 Construction in Progress - proxy for cost control',
#   3),
#  291: ('Cr_16100001 Construction in Progress - proxy for cost control, Cr_20010010 AP - Employee, Dr_60040030 Travel - Transportation',
#   1),
#  378: ('Cr_20000000 AP - Trade, Dr_11020HL3 Inter AR - HL3', 9),
#  571: ('Cr_20020HL3 Inter AP - HL3, Dr_10000000 Cash on Hands - TWD', 14),
#  200: ('Cr_11020HL3 Inter AR - HL3, Dr_20020HL3 Inter AP - HL3', 2),
#  498: ('Cr_20010010 AP - Employee, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040065 Travel - Other(expense)',
#   1),
# ...
#  540: ('Cr_20020000 AP - Intercompany, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040060 Travel - Other, Dr_60040101 Company Event - External, Dr_60040120 Entertainment, Dr_60040180 Training',
#   1),
#  694: ('Cr_60040101 Company Event - External, Dr_20020000 AP - Intercompany',
#   1),
#  536: ('Cr_20020000 AP - Intercompany, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20080000 Withholding Tax Payable, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  429: ('Cr_20000000 AP - Trade, Dr_60100000 Professional Fees', 4),
#  23: ('Cr_10000000 Cash on Hands - TWD, Dr_10010001 Restricted Cash - Time Deposit(NTD)',
#   1),
#  165: ('Cr_10010001 Restricted Cash - Time Deposit(NTD), Dr_10000050 Time Deposit - TWD',
#   1),
#  177: ('Cr_10010020 Restricted Cash - Time Deposit(USD), Dr_10010020 Restricted Cash - Time Deposit(USD)',
#   1),
#  542: ('Cr_20020000 AP - Intercompany, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040101 Company Event - External, Dr_60040120 Entertainment',
#   1),
#  528: ('Cr_20020000 AP - Intercompany, Cr_20300000 Debt - Current, Dr_10000000 Cash on Hands - TWD',
#   1),
#  661: ('Cr_30000000 Common Shares - Intercompany, Dr_10000000 Cash on Hands - TWD, Dr_20300000 Debt - Current',
#   1),
#  541: ('Cr_20020000 AP - Intercompany, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040065 Travel - Other(expense), Dr_60040101 Company Event - External, Dr_60040120 Entertainment',
#   1),
#  383: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040035 Travel - Transportation(expense)',
#   1),
#  537: ('Cr_20020000 AP - Intercompany, Dr_10000000 Cash on Hands - TWD', 1),
#  568: ('Cr_20020HL2 Inter AP - HL2, Dr_20020000 AP - Intercompany', 3),
#  583: ('Cr_2002HLHTW Inter AP - HLH TW, Cr_60040900 Other Operation Cost, Dr_20020000 AP - Intercompany',
#   1),
#  588: ('Cr_2002NPIHQ Inter AP - NPI HQ, Dr_60040900 Other Operation Cost', 1),
#  699: ('Cr_60040900 Other Operation Cost, Dr_20020000 AP - Intercompany', 1),
#  582: ('Cr_2002HLHTW Inter AP - HLH TW, Cr_30000NPI Common Shares - NPI, Dr_20400000 Other Labilities',
#   1),
#  675: ('Cr_3000YECL Common Shares - YECL, Dr_20400000 Other Labilities', 1),
#  109: ('Cr_10000020 Cash on Hands - EUR, Cr_2002HLHTW Inter AP - HLH TW, Dr_2002HLHTW Inter AP - HLH TW, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  39: ('Cr_10000000 Cash on Hands - TWD, Dr_20020HL2 Inter AP - HL2', 1),
#  570: ('Cr_20020HL2 Inter AP - HL2, Dr_20080000 Withholding Tax Payable', 11),
#  561: ('Cr_20020HL2 Inter AP - HL2, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress',
#   10),
#  279: ('Cr_16100000 Construction in Progress, Dr_20390000 Lease Liabilities - Long-term - Land',
#   1),
#  544: ('Cr_20020000 AP - Intercompany, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040101 Company Event - External, Dr_60040120 Entertainment, Dr_60040180 Training',
#   1),
#  691: ('Cr_60040101 Company Event - External, Cr_60040180 Training, Dr_20020HL2 Inter AP - HL2',
#   1),
#  385: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040100 Advertisement',
#   3),
#  519: ('Cr_20010010 AP - Employee, Dr_60040102 Company Event - Internal', 1),
#  672: ('Cr_30000NPI Common Shares - NPI, Cr_3000NPDSI Common Shares - NPDSI, Cr_3000YECL Common Shares - YECL, Cr_3000YEPL Common shares - YEPL, Dr_30000000 Common Shares - Intercompany',
#   1),
#  673: ('Cr_30000NPI Common Shares - NPI, Cr_3000YECL Common Shares - YECL, Dr_30000000 Common Shares - Intercompany',
#   7),
#  665: ('Cr_30000000 Common Shares - Intercompany, Dr_3000YECL Common Shares - YECL',
#   1),
#  567: ('Cr_20020HL2 Inter AP - HL2, Dr_20000000 AP - Trade', 6),
#  535: ('Cr_20020000 AP - Intercompany, Cr_60040035 Travel - Transportation(expense), Dr_16100000 Construction in Progress, Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040065 Travel - Other(expense), Dr_60040100 Advertisement, Dr_60040101 Company Event - External, Dr_60040102 Company Event - Internal, Dr_60040120 Entertainment, Dr_60040180 Training',
#   1),
#  569: ('Cr_20020HL2 Inter AP - HL2, Dr_20020000 AP - Intercompany, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  674: ('Cr_3000YECL Common Shares - YECL, Dr_10000000 Cash on Hands - TWD', 1),
#  581: ('Cr_2002HLHTW Inter AP - HLH TW, Cr_30000NPI Common Shares - NPI, Dr_10000020 Cash on Hands - EUR',
#   1),
#  11: ('Cr_10000000 Cash on Hands - TWD, Cr_2002HLHTW Inter AP - HLH TW, Dr_20020000 AP - Intercompany, Dr_2002HLHTW Inter AP - HLH TW',
#   1),
#  137: ('Cr_10000020 Cash on Hands - EUR, Dr_11020HL2 Inter AR - HL2', 9),
#  107: ('Cr_10000020 Cash on Hands - EUR, Cr_2002HLHTW Inter AP - HLH TW, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_2002HLHTW Inter AP - HLH TW, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  143: ('Cr_10000020 Cash on Hands - EUR, Dr_20000000 AP - Trade, Dr_70100000 Gain/Loss on Sale of Assets',
#   1),
#  269: ('Cr_16100000 Construction in Progress, Dr_19020000 Other Assets', 1),
#  566: ('Cr_20020HL2 Inter AP - HL2, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040101 Company Event - External, Dr_60040120 Entertainment, Dr_60040180 Training',
#   3),
#  195: ('Cr_11020HL2 Inter AR - HL2, Dr_11020HL2 Inter AR - HL2', 1),
#  260: ('Cr_16100000 Construction in Progress, Dr_12020010 Income Tax Receivable',
#   3),
#  27: ('Cr_10000000 Cash on Hands - TWD, Dr_11020HL2 Inter AR - HL2', 14),
#  197: ('Cr_11020HL2 Inter AR - HL2, Dr_20020HL2 Inter AP - HL2', 2),
#  277: ('Cr_16100000 Construction in Progress, Dr_20080000 Withholding Tax Payable',
#   4),
#  563: ('Cr_20020HL2 Inter AP - HL2, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040055 Travel - Meal(expense), Dr_60040065 Travel - Other(expense), Dr_60040100 Advertisement, Dr_60040101 Company Event - External, Dr_60040120 Entertainment, Dr_60040180 Training',
#   1),
#  590: ('Cr_2002NPITW Inter AP - NPI TW, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress',
#   5),
#  647: ('Cr_2070HLHB-I SHL - HLH BV - Interest , Dr_16100030 Construction in Progress - Interest Capitalization',
#   5),
#  636: ('Cr_2060EMUFG-I Bank Loan - EBL MUFG - interest payable, Dr_16100030 Construction in Progress - Interest Capitalization',
#   4),
#  574: ('Cr_20020MIT Inter AP - Mitsui, Dr_16100030 Construction in Progress - Interest Capitalization',
#   1),
#  564: ('Cr_20020HL2 Inter AP - HL2, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040045 Travel - Hotel(expense), Dr_60040101 Company Event - External, Dr_60040120 Entertainment, Dr_60040180 Training',
#   2),
#  616: ('Cr_20190000 Derivative Liability - Current, Dr_30400000 Other Comprehensive Income - Hedge accounting MTM',
#   1),
#  680: ('Cr_30400010 Other Comprehensive Income - Hedge accounting MTM tax valuation, Dr_20800000 Deferred Tax Liabilities',
#   2),
#  654: ('Cr_20800000 Deferred Tax Liabilities, Dr_30400010 Other Comprehensive Income - Hedge accounting MTM tax valuation',
#   4),
#  207: ('Cr_11020MIT Inter AR - Mitsui, Dr_16100030 Construction in Progress - Interest Capitalization',
#   2),
#  562: ('Cr_20020HL2 Inter AP - HL2, Dr_16100000 Construction in Progress', 17),
#  559: ('Cr_20020HL2 Inter AP - HL2, Dr_10000020 Cash on Hands - EUR', 3),
#  525: ('Cr_20020000 AP - Intercompany, Cr_2002YECL Inter AP - YECL, Dr_20020000 AP - Intercompany, Dr_2002YECL Inter AP - YECL',
#   1),
#  336: ('Cr_19020000 Other Assets, Dr_16100000 Construction in Progress', 1),
#  679: ('Cr_30400000 Other Comprehensive Income - Hedge accounting MTM, Dr_20190000 Derivative Liability - Current',
#   1),
#  678: ('Cr_30400000 Other Comprehensive Income - Hedge accounting MTM, Dr_14020000 Derivative Asset - Current',
#   1),
#  274: ('Cr_16100000 Construction in Progress, Dr_20020HL2 Inter AP - HL2', 1),
#  365: ('Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Dr_11080000 Input VAT, Dr_16100000 Construction in Progress, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  203: ('Cr_11020MIT Inter AR - Mitsui, Cr_2060EMUFG-I Bank Loan - EBL MUFG - interest payable, Cr_2070HLHB-I SHL - HLH BV - Interest , Dr_16100030 Construction in Progress - Interest Capitalization',
#   1),
#  122: ('Cr_10000020 Cash on Hands - EUR, Cr_70010000 Foreign Exchange Gain/Loss, Dr_2002HLHBV Inter AP - HLH BV, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  2: ('Cr_10000000 Cash on Hands - TWD, Cr_10000045 Cash on Hands - JPY, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  154: ('Cr_10000045 Cash on Hands - JPY, Dr_10000000 Cash on Hands - TWD', 1),
#  238: ('Cr_14020000 Derivative Asset - Current, Cr_30400010 Other Comprehensive Income - Hedge accounting MTM tax valuation, Dr_20800000 Deferred Tax Liabilities, Dr_30400000 Other Comprehensive Income - Hedge accounting MTM',
#   3),
#  556: ('Cr_20020HL2 Inter AP - HL2, Cr_60040035 Travel - Transportation(expense), Dr_16100000 Construction in Progress, Dr_60040101 Company Event - External, Dr_60040120 Entertainment, Dr_60040180 Training',
#   1),
#  272: ('Cr_16100000 Construction in Progress, Dr_20000000 AP - Trade, Dr_70010100 Unrealized Exchange Gain/Loss',
#   2),
#  245: ('Cr_16060000 Lease (ROU) Asset - Accumulated Amortization - Land, Dr_16100020 Construction in Progress - PL Capitalization',
#   1),
#  242: ('Cr_16050010 Lease(ROU) Asset - Interest Capitalization, Dr_16100020 Construction in Progress - PL Capitalization',
#   1),
#  324: ('Cr_16100030 Construction in Progress - Interest Capitalization, Cr_2060EDBS-I Bank Loan - EBL DBS - interest payable, Cr_2070HLHB-I SHL - HLH BV - Interest , Cr_2070MITB-I EBL - MIT - Interest , Dr_16100030 Construction in Progress - Interest Capitalization, Dr_2060EMUFG-I Bank Loan - EBL MUFG - interest payable',
#   1),
#  188: ('Cr_11020001 Accounts Receviable - Intercompany, Dr_16100030 Construction in Progress - Interest Capitalization',
#   1),
#  326: ('Cr_16100030 Construction in Progress - Interest Capitalization, Dr_11020001 Accounts Receviable - Intercompany',
#   1),
#  111: ('Cr_10000020 Cash on Hands - EUR, Cr_60325000 Interest Income, Dr_10000020 Cash on Hands - EUR, Dr_12020010 Income Tax Receivable',
#   1),
#  558: ('Cr_20020HL2 Inter AP - HL2, Dr_10000010 Cash on Hands - USD', 1),
#  368: ('Cr_20000000 AP - Trade, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  67: ('Cr_10000010 Cash on Hands - USD, Cr_20000000 AP - Trade, Cr_70010000 Foreign Exchange Gain/Loss, Dr_20000000 AP - Trade, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  121: ('Cr_10000020 Cash on Hands - EUR, Cr_70010000 Foreign Exchange Gain/Loss, Dr_2002HLHBV Inter AP - HLH BV',
#   1),
#  387: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040120 Entertainment',
#   2),
#  325: ('Cr_16100030 Construction in Progress - Interest Capitalization, Cr_2070HLHB-I SHL - HLH BV - Interest , Cr_2070MITB-I EBL - MIT - Interest , Dr_16100030 Construction in Progress - Interest Capitalization, Dr_2060EDBS-I Bank Loan - EBL DBS - interest payable, Dr_2060EMUFG-I Bank Loan - EBL MUFG - interest payable',
#   1),
#  129: ('Cr_10000020 Cash on Hands - EUR, Dr_10000010 Cash on Hands - USD, Dr_11020HL2 Inter AR - HL2',
#   1),
#  589: ('Cr_2002NPITW Inter AP - NPI TW, Cr_2002YECL Inter AP - YECL, Dr_16100000 Construction in Progress',
#   2),
#  645: ('Cr_2070HLHB-I SHL - HLH BV - Interest , Cr_2070MITB-I EBL - MIT - Interest , Dr_16100030 Construction in Progress - Interest Capitalization',
#   1),
#  635: ('Cr_2060EMUFG-I Bank Loan - EBL MUFG - interest payable, Dr_10000000 Cash on Hands - TWD, Dr_60250000 Bank Charges',
#   1),
#  240: ('Cr_16050000 Lease (ROU) Asset - Land, Cr_16060000 Lease (ROU) Asset - Accumulated Amortization - Land, Cr_16100000 Construction in Progress, Dr_16050010 Lease(ROU) Asset - Interest Capitalization, Dr_20390000 Lease Liabilities - Long-term - Land',
#   1),
#  192: ('Cr_11020HL2 Inter AR - HL2, Cr_16060001 Lease (ROU) Asset - Accumulated Amortization - Building, Cr_20390001 Lease Liabilities - Long-term - Building, Dr_16050001 Lease (ROU) Asset - Building, Dr_16100000 Construction in Progress',
#   1),
#  384: ('Cr_20000000 AP - Trade, Dr_11080000 Input VAT, Dr_60040040 Travel - Hotel',
#   1),
#  1: ('Cr_10000000 Cash on Hands - TWD, Cr_10000010 Cash on Hands - USD, Dr_10000045 Cash on Hands - JPY, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  557: ('Cr_20020HL2 Inter AP - HL2, Dr_10000000 Cash on Hands - TWD', 1),
#  630: ('Cr_2060EDBS-I Bank Loan - EBL DBS - interest payable, Dr_16100030 Construction in Progress - Interest Capitalization',
#   3),
#  640: ('Cr_2060ESMBC-I Bank Loan - EBL SMBC - interest payable, Dr_16100030 Construction in Progress - Interest Capitalization',
#   2),
#  327: ('Cr_16100030 Construction in Progress - Interest Capitalization, Dr_2060EMUFG-I Bank Loan - EBL MUFG - interest payable',
#   1),
#  328: ('Cr_16100030 Construction in Progress - Interest Capitalization, Dr_2070MITB-I EBL - MIT - Interest ',
#   1),
#  560: ('Cr_20020HL2 Inter AP - HL2, Dr_11020HL2 Inter AR - HL2', 1),
#  565: ('Cr_20020HL2 Inter AP - HL2, Dr_16100000 Construction in Progress, Dr_60040035 Travel - Transportation(expense), Dr_60040055 Travel - Meal(expense), Dr_60040101 Company Event - External, Dr_60040120 Entertainment, Dr_60040180 Training',
#   1),
#  651: ('Cr_20800000 Deferred Tax Liabilities, Cr_30400000 Other Comprehensive Income - Hedge accounting MTM, Dr_14020000 Derivative Asset - Current, Dr_30400010 Other Comprehensive Income - Hedge accounting MTM tax valuation',
#   3),
#  9: ('Cr_10000000 Cash on Hands - TWD, Cr_20020000 AP - Intercompany, Dr_20020000 AP - Intercompany, Dr_2002YECL Inter AP - YECL',
#   2),
#  94: ('Cr_10000020 Cash on Hands - EUR, Cr_12020010 Income Tax Receivable, Dr_10000000 Cash on Hands - TWD, Dr_10000010 Cash on Hands - USD',
#   1),
#  649: ('Cr_2070MITB-I EBL - MIT - Interest , Dr_16100030 Construction in Progress - Interest Capitalization',
#   1),
#  259: ('Cr_16100000 Construction in Progress, Dr_12020000 Prepaid - Others',
#   2),
#  719: ('Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_2002HLHBV Inter AP - HLH BV, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  585: ('Cr_2002HLHTW Inter AP - HLH TW, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20020000 AP - Intercompany, Dr_2002HLHTW Inter AP - HLH TW, Dr_70010000 Foreign Exchange Gain/Loss',
#   1),
#  727: ('Cr_70010000 Foreign Exchange Gain/Loss, Dr_20020HL2 Inter AP - HL2',
#   1),
#  194: ('Cr_11020HL2 Inter AR - HL2, Cr_70010000 Foreign Exchange Gain/Loss, Cr_70010100 Unrealized Exchange Gain/Loss, Dr_20020HL2 Inter AP - HL2, Dr_70010000 Foreign Exchange Gain/Loss, Dr_70010100 Unrealized Exchange Gain/Loss',
#   1),
#  196: ('Cr_11020HL2 Inter AR - HL2, Dr_11080000 Input VAT', 1),
#  551: ('Cr_20020000 AP - Intercompany, Dr_2002HLHTW Inter AP - HLH TW, Dr_2002NPITW Inter AP - NPI TW, Dr_2002YECL Inter AP - YECL',
#   1),
#  605: ('Cr_20080000 Withholding Tax Payable, Dr_20800000 Deferred Tax Liabilities',
#   1),
#  627: ('Cr_2060EDBS-I Bank Loan - EBL DBS - interest payable, Cr_2060EMUFG-I Bank Loan - EBL MUFG - interest payable, Cr_2060ESMBC-I Bank Loan - EBL SMBC - interest payable, Cr_2070HLHB-I SHL - HLH BV - Interest , Cr_2070MITB-I EBL - MIT - Interest , Dr_16100030 Construction in Progress - Interest Capitalization',
#   1)}

# %%
# Convert cluster_map dictionary to a DataFrame
cluster_map_df = pd.DataFrame.from_dict(cluster_map, orient='index', columns=['Cluster_Signature', 'Population'])
cluster_map_df.index.name = 'Cluster_ID'
cluster_map_df = cluster_map_df.reset_index()  # Make Cluster_ID a column instead of index
cluster_map_df = cluster_map_df.sort_values(by='Population', ascending=False)
cluster_map_df
# Out:
#      Cluster_ID                                  Cluster_Signature  Population
# 31           33  Cr_10000000 Cash on Hands - TWD, Dr_20000000 A...        2034
# 23          381  Cr_20000000 AP - Trade, Dr_11080000 Input VAT,...        2028
# 22          392  Cr_20000000 AP - Trade, Dr_16100000 Constructi...        1993
# 68           38  Cr_10000000 Cash on Hands - TWD, Dr_20010010 A...        1187
# 45          603  Cr_20080000 Withholding Tax Payable, Dr_200000...        1074
# ..          ...                                                ...         ...
# 461         243  Cr_16050010 Lease(ROU) Asset - Interest Capita...           1
# 460         246  Cr_16060000 Lease (ROU) Asset - Accumulated Am...           1
# 457         488  Cr_20010010 AP - Employee, Dr_60040030 Travel ...           1
# 456         318  Cr_16100010 DEVEX - Open Balance, Cr_20000000 ...           1
# 737         627  Cr_2060EDBS-I Bank Loan - EBL DBS - interest p...           1
#
# [738 rows x 3 columns]

# %% [markdown]
# ## Save

# %%
# cluster_map_df.to_excel(rf"d:\Shared\Internal Dev - JE ML\Hailong\MC2.xlsx", index=False)
